# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt
import pandas as pd
import numpy as np

#Move indicator into its own Class so that will show up in output file. 
#Reference: https://www.backtrader.com/docu/inddev.html
class RSI_Oversold(bt.Indicator):
    lines = ('oversold',)
    
    params = (
        ('level', 30),    
    )

    def __init__(self):
        self.lines.oversold = bt.indicators.RSI(self.data) < self.p.level

class Bollinger_Breakdown(bt.Indicator):
    lines = ('breakdown',)
    
    def __init__(self):
        self.lines.breakdown = self.data < bt.indicators.BBands(self.data, period=20).lines.bot        
        
class Ultimate_Oscillator(bt.Indicator):
    lines = ('uo',)
     
    params = (
        ('level', 30),    
    )
    
    # Add custom indicator logic here...currently returns value of indicator
    def __init__(self):
        self.lines.uo = bt.indicators.UltimateOscillator(self.data).lines.uo          
        
    
# Create a Strategy
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
        ("symbols", None),
        ("max_days_in_trade", 5)
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        symbols = self.p.symbols
        
        # Keep a reference to the close and forward lagged close prices as well as returns
        self.stock = self.datas[symbols.index("stockpx")]
        self.stock_px = self.stock.close
        self.stock_px_enter = self.datas[symbols.index("stockpx_lag_1")].close
        self.stock_px_exit = self.datas[symbols.index("stockpx_lag_%d" % self.p.max_days_in_trade)].close
        self.stock_returns = self.stock_px / self.stock_px(-1) - 1
        
        # Add indicators
        # Use this instead of below to be able to see full indicator (not just RSI) in output file
        self.rsi_oversold = RSI_Oversold(self.stock_px)
        #self.rsi_oversold = bt.indicators.RSI(self.stock_px) <30
        
        self.ulti_osc = Ultimate_Oscillator(self.stock) #pass in stock not just stock_px as indicator also requires high/low prices
        self.bollinger_breakdown = Bollinger_Breakdown(self.stock_px)
        
        self.in_trade = False
        self.days_in_trade = 0
        
    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.stock_px[0])
        
        size = self.position.size
        
        if(not size):
            #if self.rsi_oversold[0] > 0:
            if self.bollinger_breakdown[0] > 0:
                # replicate straddle payout less premium
                print("Indicator triggered...entering position")
                print('Exit price %.2f enter price %.2f' % (self.stock_px_exit[0], self.stock_px_enter[0]))
                if self.stock_px_exit[0] > self.stock_px_enter[0]:
                    print("Exit price will be higher than enter price. Buy!")
                    self.buy(exectype=bt.Order.Close)
                else:
                    print("Exit price will be lower than enter price. Sell!")
                    self.sell(exectype=bt.Order.Close)
                self.days_in_trade = 1
        else:
            self.days_in_trade += 1
            print("In position %d days" % self.days_in_trade)
            if self.days_in_trade == self.p.max_days_in_trade:
                print("Max days to hold trade reached...closing position")
                self.close(exectype=bt.Order.Close)
                self.days_in_trade = 0
                

if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()
    
    asset = 'MSFT'
    n_lags = 6 
    
    # Read in stock and vol data 
    datapath_vol = os.path.join('../../../datas/%s.csv' % asset) 
    datapath_stock = os.path.join('../../../datas/%s-2010-2018.csv' % asset)
    data_vol = pd.read_csv(datapath_vol, parse_dates=True,index_col=0)
    data_stock = pd.read_csv(datapath_stock, parse_dates=True,index_col=0)
    
    # Lag and merge data
    for n in np.arange(1, n_lags):
        data_stock['stockpx_lag_%d' % n ] = data_stock['Close'].shift(-n)  
    data_stock = data_stock.dropna()
    
    mergedDf = pd.concat([data_vol,data_stock], axis=1,join='inner')
    data_vol = data_vol.ix[data_vol.index & mergedDf.index]
    data_stock = data_stock.ix[data_stock.index & mergedDf.index]
    
    # Add stock price data
    cerebro.adddata(bt.feeds.PandasData(dataname=data_stock[['Close', 'High', 'Low', 'Volume']]), name='stockpx')
    
    # Add lagged stock prices to be able to replicate straddle payout
    symbol_cols = [ 'stockpx_lag_%d' % n for n in np.arange(1, n_lags)] 
    for i, symbol in enumerate(symbol_cols):
        data = data_stock[[symbol]]
        data.columns = ["Close"]
        cerebro.adddata(bt.feeds.PandasData(dataname=data), name=symbol)
    
    # Add straddle premium
    data = data_vol[['straddle']]
    data.columns = ["Close"]
    cerebro.adddata(bt.feeds.PandasData(dataname=data), name='straddle')
    
    # Add a strategy
    symbol_cols = ['stockpx'] + symbol_cols + ['straddle']
    cerebro.addstrategy(TestStrategy, symbols=symbol_cols)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Write output
    cerebro.addwriter(bt.WriterFile, out='straddle_indicators.csv',csv=True)
    
    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# /home/project/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:124: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/project/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:125: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Starting Portfolio Value: 100000.00
# 2010-02-12, Close, 27.93
# 2010-02-16, Close, 28.35
# 2010-02-17, Close, 28.59
# 2010-02-18, Close, 28.97
# 2010-02-19, Close, 28.77
# 2010-02-22, Close, 28.73
# 2010-02-23, Close, 28.33
# 2010-02-24, Close, 28.63
# 2010-02-25, Close, 28.60
# 2010-02-26, Close, 28.67
# 2010-03-01, Close, 29.02
# 2010-03-02, Close, 28.46
# 2010-03-03, Close, 28.46
# 2010-03-04, Close, 28.63
# 2010-03-05, Close, 28.59
# 2010-03-08, Close, 28.63
# 2010-03-09, Close, 28.80
# 2010-03-10, Close, 28.97
# 2010-03-11, Close, 29.18
# 2010-03-12, Close, 29.27
# 2010-03-15, Close, 29.29
# 2010-03-16, Close, 29.37
# 2010-03-17, Close, 29.63
# 2010-03-18, Close, 29.61
# 2010-03-19, Close, 29.59
# 2010-03-22, Close, 29.60
# 2010-03-23, Close, 29.88
# 2010-03-24, Close, 29.65
# 2010-03-25, Close, 30.01
# 2010-03-26, Close, 29.66
# 2010-03-29, Close, 29.59
# 2010-03-30, Close, 29.77
# 2010-03-31, Close, 29.29
# 2010-04-01, Close, 29.16
# 2010-04-05, Close, 29.27
# 2010-04-06, Close, 29.32
# 2010-04-07, Close, 29.35
# 2010-04-08, Close, 29.92
# 2010-04-09, Close, 30.34
# 2010-04-12, Close, 30.32
# 2010-04-13, Close, 30.45
# 2010-04-14, Close, 30.82
# 2010-04-15, Close, 30.87
# 2010-04-16, Close, 30.67
# 2010-04-19, Close, 31.04
# 2010-04-20, Close, 31.36
# 2010-04-21, Close, 31.33
# 2010-04-22, Close, 31.39
# 2010-04-23, Close, 30.96
# 2010-04-26, Close, 31.11
# 2010-04-27, Close, 30.85
# 2010-04-28, Close, 30.91
# 2010-04-29, Close, 31.00
# 2010-04-30, Close, 30.54
# 2010-05-03, Close, 30.86
# 2010-05-04, Close, 30.13
# 2010-05-05, Close, 29.85
# Indicator triggered...entering position
# Exit price 29.44 enter price 28.98
# Exit price will be higher than enter price. Buy!
# 2010-05-06, Close, 28.98
# In position 2 days
# 2010-05-07, Close, 28.21
# In position 3 days
# 2010-05-10, Close, 28.94
# In position 4 days
# 2010-05-11, Close, 28.88
# In position 5 days
# Max days to hold trade reached...closing position
# 2010-05-12, Close, 29.44
# 2010-05-13, Close, 29.24
# 2010-05-14, Close, 28.93
# 2010-05-17, Close, 28.94
# 2010-05-18, Close, 28.60
# 2010-05-19, Close, 28.24
# 2010-05-20, Close, 27.11
# Indicator triggered...entering position
# Exit price 26.00 enter price 26.84
# Exit price will be lower than enter price. Sell!
# 2010-05-21, Close, 26.84
# In position 2 days
# 2010-05-24, Close, 26.27
# In position 3 days
# 2010-05-25, Close, 26.07
# In position 4 days
# 2010-05-26, Close, 25.01
# In position 5 days
# Max days to hold trade reached...closing position
# 2010-05-27, Close, 26.00
# 2010-05-28, Close, 25.80
# 2010-06-01, Close, 25.89
# 2010-06-02, Close, 26.46
# 2010-06-03, Close, 26.86
# 2010-06-04, Close, 25.79
# 2010-06-07, Close, 25.29
# 2010-06-08, Close, 25.11
# 2010-06-09, Close, 24.79
# 2010-06-10, Close, 25.00
# 2010-06-11, Close, 25.66
# 2010-06-14, Close, 25.50
# 2010-06-15, Close, 26.58
# 2010-06-16, Close, 26.32
# 2010-06-17, Close, 26.37
# 2010-06-18, Close, 26.44
# 2010-06-21, Close, 25.95
# 2010-06-22, Close, 25.77
# 2010-06-23, Close, 25.31
# 2010-06-24, Close, 25.00
# 2010-06-25, Close, 24.53
# 2010-06-28, Close, 24.31
# 2010-06-29, Close, 23.31
# Indicator triggered...entering position
# Exit price 24.30 enter price 23.01
# Exit price will be higher than enter price. Buy!
# 2010-06-30, Close, 23.01
# In position 2 days
# 2010-07-01, Close, 23.16
# In position 3 days
# 2010-07-02, Close, 23.27
# In position 4 days
# 2010-07-06, Close, 23.82
# In position 5 days
# Max days to hold trade reached...closing position
# 2010-07-07, Close, 24.30
# 2010-07-08, Close, 24.41
# 2010-07-09, Close, 24.27
# 2010-07-12, Close, 24.83
# 2010-07-13, Close, 25.13
# 2010-07-14, Close, 25.44
# 2010-07-15, Close, 25.51
# 2010-07-16, Close, 24.89
# 2010-07-19, Close, 25.23
# 2010-07-20, Close, 25.48
# 2010-07-21, Close, 25.12
# 2010-07-22, Close, 25.84
# 2010-07-23, Close, 25.81
# 2010-07-26, Close, 26.10
# 2010-07-27, Close, 26.16
# 2010-07-28, Close, 25.95
# 2010-07-29, Close, 26.03
# 2010-07-30, Close, 25.81
# 2010-08-02, Close, 26.33
# 2010-08-03, Close, 26.16
# 2010-08-04, Close, 25.73
# 2010-08-05, Close, 25.37
# 2010-08-06, Close, 25.55
# 2010-08-09, Close, 25.61
# 2010-08-10, Close, 25.07
# 2010-08-11, Close, 24.86
# 2010-08-12, Close, 24.49
# Indicator triggered...entering position
# Exit price 24.44 enter price 24.40
# Exit price will be higher than enter price. Buy!
# 2010-08-13, Close, 24.40
# In position 2 days
# 2010-08-16, Close, 24.50
# In position 3 days
# 2010-08-17, Close, 24.71
# In position 4 days
# 2010-08-18, Close, 24.82
# In position 5 days
# Max days to hold trade reached...closing position
# 2010-08-19, Close, 24.44
# 2010-08-20, Close, 24.23
# 2010-08-23, Close, 24.28
# 2010-08-24, Close, 24.04
# 2010-08-25, Close, 24.10
# 2010-08-26, Close, 23.82
# 2010-08-27, Close, 23.93
# 2010-08-30, Close, 23.64
# 2010-08-31, Close, 23.47
# 2010-09-01, Close, 23.90
# 2010-09-02, Close, 23.94
# 2010-09-03, Close, 24.29
# 2010-09-07, Close, 23.96
# 2010-09-08, Close, 23.93
# 2010-09-09, Close, 24.01
# 2010-09-10, Close, 23.85
# 2010-09-13, Close, 25.11
# 2010-09-14, Close, 25.03
# 2010-09-15, Close, 25.12
# 2010-09-16, Close, 25.33
# 2010-09-17, Close, 25.22
# 2010-09-20, Close, 25.43
# 2010-09-21, Close, 25.15
# 2010-09-22, Close, 24.61
# 2010-09-23, Close, 24.43
# 2010-09-24, Close, 24.78
# 2010-09-27, Close, 24.73
# 2010-09-28, Close, 24.68
# 2010-09-29, Close, 24.50
# 2010-09-30, Close, 24.49
# 2010-10-01, Close, 24.38
# 2010-10-04, Close, 23.91
# 2010-10-05, Close, 24.35
# 2010-10-06, Close, 24.43
# 2010-10-07, Close, 24.53
# 2010-10-08, Close, 24.57
# 2010-10-12, Close, 24.83
# 2010-10-13, Close, 25.34
# 2010-10-14, Close, 25.23
# 2010-10-15, Close, 25.54
# 2010-10-18, Close, 25.82
# 2010-10-19, Close, 25.10
# 2010-10-20, Close, 25.31
# 2010-10-21, Close, 25.42
# 2010-10-22, Close, 25.38
# 2010-10-25, Close, 25.19
# 2010-10-26, Close, 25.90
# 2010-10-27, Close, 26.05
# 2010-10-28, Close, 26.28
# 2010-10-29, Close, 26.67
# 2010-11-01, Close, 26.95
# 2010-11-02, Close, 27.39
# 2010-11-03, Close, 27.03
# 2010-11-04, Close, 27.14
# 2010-11-05, Close, 26.85
# 2010-11-08, Close, 26.81
# 2010-11-09, Close, 26.95
# 2010-11-10, Close, 26.94
# 2010-11-12, Close, 26.27
# 2010-11-15, Close, 26.20
# 2010-11-16, Close, 25.81
# 2010-11-17, Close, 25.57
# 2010-11-18, Close, 25.84
# 2010-11-19, Close, 25.69
# 2010-11-22, Close, 25.73
# 2010-11-23, Close, 25.12
# Indicator triggered...entering position
# Exit price 26.04 enter price 25.37
# Exit price will be higher than enter price. Buy!
# 2010-11-24, Close, 25.37
# In position 2 days
# 2010-11-26, Close, 25.25
# In position 3 days
# 2010-11-29, Close, 25.31
# In position 4 days
# 2010-11-30, Close, 25.26
# In position 5 days
# Max days to hold trade reached...closing position
# 2010-12-01, Close, 26.04
# 2010-12-02, Close, 26.89
# 2010-12-03, Close, 27.02
# 2010-12-06, Close, 26.84
# 2010-12-07, Close, 26.87
# 2010-12-08, Close, 27.23
# 2010-12-09, Close, 27.08
# 2010-12-10, Close, 27.34
# 2010-12-13, Close, 27.25
# 2010-12-14, Close, 27.62
# 2010-12-15, Close, 27.85
# 2010-12-16, Close, 27.99
# 2010-12-17, Close, 27.90
# 2010-12-20, Close, 27.81
# 2010-12-21, Close, 28.07
# 2010-12-22, Close, 28.19
# 2010-12-23, Close, 28.30
# 2010-12-27, Close, 28.07
# 2010-12-28, Close, 28.01
# 2010-12-29, Close, 27.97
# 2010-12-30, Close, 27.85
# 2010-12-31, Close, 27.91
# 2011-01-03, Close, 27.98
# 2011-01-04, Close, 28.09
# 2011-01-05, Close, 28.00
# 2011-01-06, Close, 28.82
# 2011-01-07, Close, 28.60
# 2011-01-10, Close, 28.22
# 2011-01-11, Close, 28.11
# 2011-01-12, Close, 28.55
# 2011-01-13, Close, 28.19
# 2011-01-14, Close, 28.30
# 2011-01-18, Close, 28.66
# 2011-01-19, Close, 28.47
# 2011-01-20, Close, 28.35
# 2011-01-21, Close, 28.02
# 2011-01-24, Close, 28.38
# 2011-01-25, Close, 28.45
# 2011-01-26, Close, 28.78
# 2011-01-27, Close, 28.87
# 2011-01-28, Close, 27.75
# 2011-01-31, Close, 27.73
# 2011-02-01, Close, 27.99
# 2011-02-02, Close, 27.94
# 2011-02-03, Close, 27.65
# 2011-02-04, Close, 27.77
# 2011-02-07, Close, 28.20
# 2011-02-08, Close, 28.28
# 2011-02-09, Close, 27.97
# 2011-02-10, Close, 27.50
# 2011-02-11, Close, 27.25
# Indicator triggered...entering position
# Exit price 27.06 enter price 27.23
# Exit price will be lower than enter price. Sell!
# 2011-02-14, Close, 27.23
# In position 2 days
# 2011-02-15, Close, 26.96
# In position 3 days
# 2011-02-16, Close, 27.02
# In position 4 days
# 2011-02-17, Close, 27.21
# In position 5 days
# Max days to hold trade reached...closing position
# 2011-02-18, Close, 27.06
# 2011-02-22, Close, 26.59
# 2011-02-23, Close, 26.59
# 2011-02-24, Close, 26.77
# 2011-02-25, Close, 26.55
# 2011-02-28, Close, 26.58
# 2011-03-01, Close, 26.16
# 2011-03-02, Close, 26.08
# 2011-03-03, Close, 26.20
# 2011-03-04, Close, 25.95
# 2011-03-07, Close, 25.72
# 2011-03-08, Close, 25.91
# 2011-03-09, Close, 25.89
# 2011-03-10, Close, 25.41
# 2011-03-11, Close, 25.68
# 2011-03-14, Close, 25.69
# 2011-03-15, Close, 25.39
# 2011-03-16, Close, 24.79
# Indicator triggered...entering position
# Exit price 25.54 enter price 24.78
# Exit price will be higher than enter price. Buy!
# 2011-03-17, Close, 24.78
# In position 2 days
# 2011-03-18, Close, 24.80
# In position 3 days
# 2011-03-21, Close, 25.33
# In position 4 days
# 2011-03-22, Close, 25.30
# In position 5 days
# Max days to hold trade reached...closing position
# 2011-03-23, Close, 25.54
# 2011-03-24, Close, 25.81
# 2011-03-25, Close, 25.62
# 2011-03-28, Close, 25.41
# 2011-03-29, Close, 25.49
# 2011-03-30, Close, 25.61
# 2011-03-31, Close, 25.39
# 2011-04-01, Close, 25.48
# 2011-04-04, Close, 25.55
# 2011-04-05, Close, 25.78
# 2011-04-06, Close, 26.15
# 2011-04-07, Close, 26.20
# 2011-04-08, Close, 26.07
# 2011-04-11, Close, 25.98
# 2011-04-12, Close, 25.64
# 2011-04-13, Close, 25.63
# 2011-04-14, Close, 25.42
# 2011-04-15, Close, 25.37
# 2011-04-18, Close, 25.08
# 2011-04-19, Close, 25.15
# 2011-04-20, Close, 25.76
# 2011-04-21, Close, 25.52
# 2011-04-25, Close, 25.61
# 2011-04-26, Close, 26.19
# 2011-04-27, Close, 26.38
# 2011-04-28, Close, 26.71
# 2011-04-29, Close, 25.92
# 2011-05-02, Close, 25.66
# 2011-05-03, Close, 25.81
# 2011-05-04, Close, 26.06
# 2011-05-05, Close, 25.79
# 2011-05-06, Close, 25.87
# 2011-05-09, Close, 25.83
# 2011-05-10, Close, 25.67
# 2011-05-11, Close, 25.36
# 2011-05-12, Close, 25.32
# 2011-05-13, Close, 25.03
# 2011-05-16, Close, 24.57
# Indicator triggered...entering position
# Exit price 24.17 enter price 24.52
# Exit price will be lower than enter price. Sell!
# 2011-05-17, Close, 24.52
# In position 2 days
# 2011-05-18, Close, 24.69
# In position 3 days
# 2011-05-19, Close, 24.72
# In position 4 days
# 2011-05-20, Close, 24.49
# In position 5 days
# Max days to hold trade reached...closing position
# 2011-05-23, Close, 24.17
# 2011-05-24, Close, 24.15
# 2011-05-25, Close, 24.19
# 2011-05-26, Close, 24.67
# 2011-05-27, Close, 24.76
# 2011-05-31, Close, 25.01
# 2011-06-01, Close, 24.43
# 2011-06-02, Close, 24.22
# 2011-06-03, Close, 23.91
# 2011-06-06, Close, 24.01
# 2011-06-07, Close, 24.06
# 2011-06-08, Close, 23.94
# 2011-06-09, Close, 23.96
# 2011-06-10, Close, 23.71
# 2011-06-13, Close, 24.04
# 2011-06-14, Close, 24.22
# 2011-06-15, Close, 23.74
# 2011-06-16, Close, 24.00
# 2011-06-17, Close, 24.26
# 2011-06-20, Close, 24.47
# 2011-06-21, Close, 24.76
# 2011-06-22, Close, 24.65
# 2011-06-23, Close, 24.63
# 2011-06-24, Close, 24.30
# 2011-06-27, Close, 25.20
# 2011-06-28, Close, 25.80
# 2011-06-29, Close, 25.62
# 2011-06-30, Close, 26.00
# 2011-07-01, Close, 26.02
# 2011-07-05, Close, 26.03
# 2011-07-06, Close, 26.33
# 2011-07-07, Close, 26.77
# 2011-07-08, Close, 26.92
# 2011-07-11, Close, 26.63
# 2011-07-12, Close, 26.54
# 2011-07-13, Close, 26.63
# 2011-07-14, Close, 26.47
# 2011-07-15, Close, 26.78
# 2011-07-18, Close, 26.59
# 2011-07-19, Close, 27.54
# 2011-07-20, Close, 27.06
# 2011-07-21, Close, 27.10
# 2011-07-22, Close, 27.53
# 2011-07-25, Close, 27.91
# 2011-07-26, Close, 28.08
# 2011-07-27, Close, 27.33
# 2011-07-28, Close, 27.72
# 2011-07-29, Close, 27.40
# 2011-08-01, Close, 27.27
# 2011-08-02, Close, 26.80
# 2011-08-03, Close, 26.92
# 2011-08-04, Close, 25.94
# Indicator triggered...entering position
# Exit price 25.19 enter price 25.68
# Exit price will be lower than enter price. Sell!
# 2011-08-05, Close, 25.68
# In position 2 days
# 2011-08-08, Close, 24.48
# In position 3 days
# 2011-08-09, Close, 25.58
# In position 4 days
# 2011-08-10, Close, 24.20
# In position 5 days
# Max days to hold trade reached...closing position
# 2011-08-11, Close, 25.19
# 2011-08-12, Close, 25.10
# 2011-08-15, Close, 25.51
# 2011-08-16, Close, 25.35
# 2011-08-17, Close, 25.25
# 2011-08-18, Close, 24.67
# 2011-08-19, Close, 24.05
# 2011-08-22, Close, 23.98
# 2011-08-23, Close, 24.72
# 2011-08-24, Close, 24.90
# 2011-08-25, Close, 24.57
# 2011-08-26, Close, 25.25
# 2011-08-29, Close, 25.84
# 2011-08-30, Close, 26.23
# 2011-08-31, Close, 26.60
# 2011-09-01, Close, 26.21
# 2011-09-02, Close, 25.80
# 2011-09-06, Close, 25.51
# 2011-09-07, Close, 26.00
# 2011-09-08, Close, 26.22
# 2011-09-09, Close, 25.74
# 2011-09-12, Close, 25.89
# 2011-09-13, Close, 26.04
# 2011-09-14, Close, 26.50
# 2011-09-15, Close, 26.99
# 2011-09-16, Close, 27.12
# 2011-09-19, Close, 27.21
# 2011-09-20, Close, 26.98
# 2011-09-21, Close, 25.99
# 2011-09-22, Close, 25.06
# 2011-09-23, Close, 25.06
# 2011-09-26, Close, 25.44
# 2011-09-27, Close, 25.67
# 2011-09-28, Close, 25.58
# 2011-09-29, Close, 25.45
# 2011-09-30, Close, 24.89
# 2011-10-03, Close, 24.53
# 2011-10-04, Close, 25.34
# 2011-10-05, Close, 25.89
# 2011-10-06, Close, 26.34
# 2011-10-07, Close, 26.25
# 2011-10-11, Close, 27.00
# 2011-10-12, Close, 26.96
# 2011-10-13, Close, 27.18
# 2011-10-14, Close, 27.27
# 2011-10-17, Close, 26.98
# 2011-10-18, Close, 27.31
# 2011-10-19, Close, 27.13
# 2011-10-20, Close, 27.04
# 2011-10-21, Close, 27.16
# 2011-10-24, Close, 27.19
# 2011-10-25, Close, 26.81
# 2011-10-26, Close, 26.59
# 2011-10-27, Close, 27.25
# 2011-10-28, Close, 26.98
# 2011-10-31, Close, 26.63
# 2011-11-01, Close, 25.99
# 2011-11-02, Close, 26.01
# 2011-11-03, Close, 26.53
# 2011-11-04, Close, 26.25
# 2011-11-07, Close, 26.80
# 2011-11-08, Close, 27.16
# 2011-11-09, Close, 26.20
# 2011-11-10, Close, 26.28
# 2011-11-14, Close, 26.76
# 2011-11-15, Close, 26.74
# 2011-11-16, Close, 26.07
# 2011-11-17, Close, 25.54
# Indicator triggered...entering position
# Exit price 24.30 enter price 25.30
# Exit price will be lower than enter price. Sell!
# 2011-11-18, Close, 25.30
# In position 2 days
# 2011-11-21, Close, 25.00
# In position 3 days
# 2011-11-22, Close, 24.79
# In position 4 days
# 2011-11-23, Close, 24.47
# In position 5 days
# Max days to hold trade reached...closing position
# 2011-11-25, Close, 24.30
# Indicator triggered...entering position
# Exit price 25.22 enter price 24.87
# Exit price will be higher than enter price. Buy!
# 2011-11-28, Close, 24.87
# In position 2 days
# 2011-11-29, Close, 24.84
# In position 3 days
# 2011-11-30, Close, 25.58
# In position 4 days
# 2011-12-01, Close, 25.28
# In position 5 days
# Max days to hold trade reached...closing position
# 2011-12-02, Close, 25.22
# 2011-12-05, Close, 25.70
# 2011-12-06, Close, 25.66
# 2011-12-07, Close, 25.60
# 2011-12-08, Close, 25.40
# 2011-12-09, Close, 25.70
# 2011-12-12, Close, 25.51
# 2011-12-13, Close, 25.76
# 2011-12-14, Close, 25.59
# 2011-12-15, Close, 25.56
# 2011-12-16, Close, 26.00
# 2011-12-19, Close, 25.53
# 2011-12-20, Close, 26.03
# 2011-12-21, Close, 25.76
# 2011-12-22, Close, 25.81
# 2011-12-23, Close, 26.03
# 2011-12-27, Close, 26.04
# 2011-12-28, Close, 25.82
# 2011-12-29, Close, 26.02
# 2011-12-30, Close, 25.96
# 2012-01-03, Close, 26.77
# 2012-01-04, Close, 27.40
# 2012-01-05, Close, 27.68
# 2012-01-06, Close, 28.11
# 2012-01-09, Close, 27.74
# 2012-01-10, Close, 27.84
# 2012-01-11, Close, 27.72
# 2012-01-12, Close, 28.00
# 2012-01-13, Close, 28.25
# 2012-01-17, Close, 28.26
# 2012-01-18, Close, 28.23
# 2012-01-19, Close, 28.12
# 2012-01-20, Close, 29.71
# 2012-01-23, Close, 29.73
# 2012-01-24, Close, 29.34
# 2012-01-25, Close, 29.56
# 2012-01-26, Close, 29.50
# 2012-01-27, Close, 29.23
# 2012-01-30, Close, 29.61
# 2012-01-31, Close, 29.53
# 2012-02-01, Close, 29.89
# 2012-02-02, Close, 29.95
# 2012-02-03, Close, 30.24
# 2012-02-06, Close, 30.20
# 2012-02-07, Close, 30.35
# 2012-02-08, Close, 30.66
# 2012-02-09, Close, 30.77
# 2012-02-10, Close, 30.50
# 2012-02-13, Close, 30.58
# 2012-02-14, Close, 30.25
# 2012-02-15, Close, 30.05
# 2012-02-16, Close, 31.29
# 2012-02-17, Close, 31.25
# 2012-02-21, Close, 31.44
# 2012-02-22, Close, 31.27
# 2012-02-23, Close, 31.37
# 2012-02-24, Close, 31.48
# 2012-02-27, Close, 31.35
# 2012-02-28, Close, 31.87
# 2012-02-29, Close, 31.74
# 2012-03-01, Close, 32.29
# 2012-03-02, Close, 32.08
# 2012-03-05, Close, 31.80
# 2012-03-06, Close, 31.56
# 2012-03-07, Close, 31.84
# 2012-03-08, Close, 32.01
# 2012-03-09, Close, 31.99
# 2012-03-12, Close, 32.04
# 2012-03-13, Close, 32.67
# 2012-03-14, Close, 32.77
# 2012-03-15, Close, 32.85
# 2012-03-16, Close, 32.60
# 2012-03-19, Close, 32.20
# 2012-03-20, Close, 31.99
# 2012-03-21, Close, 31.91
# 2012-03-22, Close, 32.00
# 2012-03-23, Close, 32.01
# 2012-03-26, Close, 32.59
# 2012-03-27, Close, 32.52
# 2012-03-28, Close, 32.19
# 2012-03-29, Close, 32.12
# 2012-03-30, Close, 32.26
# 2012-04-02, Close, 32.29
# 2012-04-03, Close, 31.94
# 2012-04-04, Close, 31.21
# Indicator triggered...entering position
# Exit price 30.98 enter price 31.52
# Exit price will be lower than enter price. Sell!
# 2012-04-05, Close, 31.52
# In position 2 days
# 2012-04-09, Close, 31.10
# In position 3 days
# 2012-04-10, Close, 30.47
# In position 4 days
# 2012-04-11, Close, 30.35
# In position 5 days
# Max days to hold trade reached...closing position
# 2012-04-12, Close, 30.98
# 2012-04-13, Close, 30.81
# 2012-04-16, Close, 31.08
# 2012-04-17, Close, 31.44
# 2012-04-18, Close, 31.14
# 2012-04-19, Close, 31.01
# 2012-04-20, Close, 32.42
# 2012-04-23, Close, 32.12
# 2012-04-24, Close, 31.92
# 2012-04-25, Close, 32.20
# 2012-04-26, Close, 32.11
# 2012-04-27, Close, 31.98
# 2012-04-30, Close, 32.02
# 2012-05-01, Close, 32.01
# 2012-05-02, Close, 31.80
# 2012-05-03, Close, 31.76
# 2012-05-04, Close, 30.98
# 2012-05-07, Close, 30.65
# 2012-05-08, Close, 30.50
# 2012-05-09, Close, 30.76
# 2012-05-10, Close, 30.74
# 2012-05-11, Close, 31.16
# 2012-05-14, Close, 30.68
# 2012-05-15, Close, 30.21
# 2012-05-16, Close, 29.90
# 2012-05-17, Close, 29.72
# 2012-05-18, Close, 29.27
# Indicator triggered...entering position
# Exit price 29.06 enter price 29.75
# Exit price will be lower than enter price. Sell!
# 2012-05-21, Close, 29.75
# In position 2 days
# 2012-05-22, Close, 29.76
# In position 3 days
# 2012-05-23, Close, 29.11
# In position 4 days
# 2012-05-24, Close, 29.07
# In position 5 days
# Max days to hold trade reached...closing position
# 2012-05-25, Close, 29.06
# 2012-05-29, Close, 29.56
# 2012-05-30, Close, 29.34
# 2012-05-31, Close, 29.19
# 2012-06-01, Close, 28.45
# 2012-06-04, Close, 28.55
# 2012-06-05, Close, 28.51
# 2012-06-06, Close, 29.35
# 2012-06-07, Close, 29.23
# 2012-06-08, Close, 29.65
# 2012-06-11, Close, 28.90
# 2012-06-12, Close, 29.29
# 2012-06-13, Close, 29.13
# 2012-06-14, Close, 29.34
# 2012-06-15, Close, 30.02
# 2012-06-18, Close, 29.84
# 2012-06-19, Close, 30.70
# 2012-06-20, Close, 30.93
# 2012-06-21, Close, 30.14
# 2012-06-22, Close, 30.70
# 2012-06-25, Close, 29.87
# 2012-06-26, Close, 30.02
# 2012-06-27, Close, 30.17
# 2012-06-28, Close, 29.91
# 2012-06-29, Close, 30.59
# 2012-07-02, Close, 30.56
# 2012-07-03, Close, 30.76
# 2012-07-05, Close, 30.70
# 2012-07-06, Close, 30.19
# 2012-07-09, Close, 30.00
# 2012-07-10, Close, 29.74
# 2012-07-11, Close, 29.30
# 2012-07-12, Close, 28.63
# Indicator triggered...entering position
# Exit price 30.67 enter price 29.39
# Exit price will be higher than enter price. Buy!
# 2012-07-13, Close, 29.39
# In position 2 days
# 2012-07-16, Close, 29.44
# In position 3 days
# 2012-07-17, Close, 29.66
# In position 4 days
# 2012-07-18, Close, 30.45
# In position 5 days
# Max days to hold trade reached...closing position
# 2012-07-19, Close, 30.67
# 2012-07-20, Close, 30.12
# 2012-07-23, Close, 29.28
# 2012-07-24, Close, 29.15
# 2012-07-25, Close, 28.83
# 2012-07-26, Close, 29.16
# 2012-07-27, Close, 29.76
# 2012-07-30, Close, 29.64
# 2012-07-31, Close, 29.47
# 2012-08-01, Close, 29.41
# 2012-08-02, Close, 29.19
# 2012-08-03, Close, 29.75
# 2012-08-06, Close, 29.95
# 2012-08-07, Close, 30.26
# 2012-08-08, Close, 30.33
# 2012-08-09, Close, 30.50
# 2012-08-10, Close, 30.42
# 2012-08-13, Close, 30.39
# 2012-08-14, Close, 30.13
# 2012-08-15, Close, 30.20
# 2012-08-16, Close, 30.78
# 2012-08-17, Close, 30.90
# 2012-08-20, Close, 30.74
# 2012-08-21, Close, 30.80
# 2012-08-22, Close, 30.54
# 2012-08-23, Close, 30.26
# 2012-08-24, Close, 30.56
# 2012-08-27, Close, 30.69
# 2012-08-28, Close, 30.63
# 2012-08-29, Close, 30.65
# 2012-08-30, Close, 30.32
# 2012-08-31, Close, 30.82
# 2012-09-04, Close, 30.39
# 2012-09-05, Close, 30.39
# 2012-09-06, Close, 31.35
# 2012-09-07, Close, 30.95
# 2012-09-10, Close, 30.72
# 2012-09-11, Close, 30.79
# 2012-09-12, Close, 30.78
# 2012-09-13, Close, 30.94
# 2012-09-14, Close, 31.21
# 2012-09-17, Close, 31.21
# 2012-09-18, Close, 31.18
# 2012-09-19, Close, 31.05
# 2012-09-20, Close, 31.45
# 2012-09-21, Close, 31.19
# 2012-09-24, Close, 30.78
# 2012-09-25, Close, 30.39
# 2012-09-26, Close, 30.17
# 2012-09-27, Close, 30.16
# 2012-09-28, Close, 29.76
# Indicator triggered...entering position
# Exit price 29.85 enter price 29.49
# Exit price will be higher than enter price. Buy!
# 2012-10-01, Close, 29.49
# In position 2 days
# 2012-10-02, Close, 29.66
# In position 3 days
# 2012-10-03, Close, 29.86
# In position 4 days
# 2012-10-04, Close, 30.03
# In position 5 days
# Max days to hold trade reached...closing position
# 2012-10-05, Close, 29.85
# 2012-10-09, Close, 29.28
# 2012-10-10, Close, 28.98
# 2012-10-11, Close, 28.95
# 2012-10-12, Close, 29.20
# 2012-10-15, Close, 29.51
# 2012-10-16, Close, 29.49
# 2012-10-17, Close, 29.59
# 2012-10-18, Close, 29.50
# 2012-10-19, Close, 28.64
# 2012-10-22, Close, 28.00
# Indicator triggered...entering position
# Exit price 28.54 enter price 28.05
# Exit price will be higher than enter price. Buy!
# 2012-10-23, Close, 28.05
# In position 2 days
# 2012-10-24, Close, 27.90
# In position 3 days
# 2012-10-25, Close, 27.88
# In position 4 days
# 2012-10-26, Close, 28.21
# In position 5 days
# Max days to hold trade reached...closing position
# 2012-11-01, Close, 29.52
# 2012-11-02, Close, 29.50
# 2012-11-05, Close, 29.63
# 2012-11-06, Close, 29.86
# 2012-11-07, Close, 29.08
# 2012-11-08, Close, 28.81
# 2012-11-09, Close, 28.83
# 2012-11-13, Close, 27.09
# Indicator triggered...entering position
# Exit price 26.71 enter price 26.84
# Exit price will be lower than enter price. Sell!
# 2012-11-14, Close, 26.84
# In position 2 days
# 2012-11-15, Close, 26.66
# In position 3 days
# 2012-11-16, Close, 26.52
# In position 4 days
# 2012-11-19, Close, 26.73
# In position 5 days
# Max days to hold trade reached...closing position
# 2012-11-20, Close, 26.71
# 2012-11-21, Close, 26.95
# 2012-11-23, Close, 27.70
# 2012-11-26, Close, 27.39
# 2012-11-27, Close, 27.08
# 2012-11-28, Close, 27.36
# 2012-11-29, Close, 26.95
# 2012-11-30, Close, 26.62
# 2012-12-03, Close, 26.43
# 2012-12-04, Close, 26.37
# 2012-12-05, Close, 26.67
# 2012-12-06, Close, 26.73
# 2012-12-07, Close, 26.46
# 2012-12-10, Close, 26.94
# 2012-12-11, Close, 27.32
# 2012-12-12, Close, 27.24
# 2012-12-13, Close, 27.11
# 2012-12-14, Close, 26.81
# 2012-12-17, Close, 27.10
# 2012-12-18, Close, 27.56
# 2012-12-19, Close, 27.31
# 2012-12-20, Close, 27.68
# 2012-12-21, Close, 27.45
# 2012-12-24, Close, 27.06
# 2012-12-26, Close, 26.86
# 2012-12-27, Close, 26.96
# 2012-12-28, Close, 26.55
# 2012-12-31, Close, 26.71
# 2013-01-03, Close, 27.25
# 2013-01-04, Close, 26.74
# 2013-01-07, Close, 26.69
# 2013-01-08, Close, 26.55
# 2013-01-09, Close, 26.70
# 2013-01-10, Close, 26.46
# 2013-01-11, Close, 26.83
# 2013-01-14, Close, 26.89
# 2013-01-15, Close, 27.21
# 2013-01-16, Close, 27.04
# 2013-01-17, Close, 27.25
# 2013-01-18, Close, 27.25
# 2013-01-22, Close, 27.15
# 2013-01-23, Close, 27.61
# 2013-01-24, Close, 27.63
# 2013-01-25, Close, 27.88
# 2013-01-28, Close, 27.91
# 2013-01-29, Close, 28.01
# 2013-01-30, Close, 27.85
# 2013-01-31, Close, 27.45
# 2013-02-01, Close, 27.93
# 2013-02-04, Close, 27.44
# 2013-02-05, Close, 27.50
# 2013-02-06, Close, 27.34
# 2013-02-07, Close, 27.28
# 2013-02-08, Close, 27.55
# 2013-02-11, Close, 27.86
# 2013-02-12, Close, 27.88
# 2013-02-13, Close, 28.03
# 2013-02-14, Close, 28.04
# 2013-02-15, Close, 28.01
# 2013-02-19, Close, 28.05
# 2013-02-20, Close, 27.87
# 2013-02-21, Close, 27.49
# 2013-02-22, Close, 27.76
# 2013-02-25, Close, 27.37
# 2013-02-26, Close, 27.37
# 2013-02-27, Close, 27.81
# 2013-02-28, Close, 27.80
# 2013-03-01, Close, 27.95
# 2013-03-04, Close, 28.15
# 2013-03-05, Close, 28.35
# 2013-03-06, Close, 28.09
# 2013-03-07, Close, 28.14
# 2013-03-08, Close, 28.00
# 2013-03-11, Close, 27.87
# 2013-03-12, Close, 27.91
# 2013-03-13, Close, 27.92
# 2013-03-14, Close, 28.14
# 2013-03-15, Close, 28.04
# 2013-03-18, Close, 28.10
# 2013-03-19, Close, 28.18
# 2013-03-20, Close, 28.32
# 2013-03-21, Close, 28.11
# 2013-03-22, Close, 28.25
# 2013-03-25, Close, 28.16
# 2013-03-26, Close, 28.16
# 2013-03-27, Close, 28.37
# 2013-03-28, Close, 28.61
# 2013-04-01, Close, 28.61
# 2013-04-02, Close, 28.80
# 2013-04-03, Close, 28.56
# 2013-04-04, Close, 28.60
# 2013-04-05, Close, 28.70
# 2013-04-08, Close, 28.59
# 2013-04-09, Close, 29.61
# 2013-04-10, Close, 30.28
# 2013-04-11, Close, 28.94
# 2013-04-12, Close, 28.79
# 2013-04-15, Close, 28.69
# 2013-04-16, Close, 28.97
# 2013-04-17, Close, 28.83
# 2013-04-18, Close, 28.79
# 2013-04-19, Close, 29.77
# 2013-04-22, Close, 30.83
# 2013-04-23, Close, 30.60
# 2013-04-24, Close, 31.76
# 2013-04-25, Close, 31.94
# 2013-04-26, Close, 31.79
# 2013-04-29, Close, 32.61
# 2013-04-30, Close, 33.10
# 2013-05-01, Close, 32.72
# 2013-05-02, Close, 33.16
# 2013-05-03, Close, 33.49
# 2013-05-06, Close, 33.75
# 2013-05-07, Close, 33.31
# 2013-05-08, Close, 32.99
# 2013-05-09, Close, 32.66
# 2013-05-10, Close, 32.69
# 2013-05-13, Close, 33.03
# 2013-05-14, Close, 33.53
# 2013-05-15, Close, 33.85
# 2013-05-16, Close, 34.08
# 2013-05-17, Close, 34.87
# 2013-05-20, Close, 35.08
# 2013-05-21, Close, 34.85
# 2013-05-22, Close, 34.61
# 2013-05-23, Close, 34.15
# 2013-05-24, Close, 34.27
# 2013-05-28, Close, 35.02
# 2013-05-29, Close, 34.88
# 2013-05-30, Close, 35.03
# 2013-05-31, Close, 34.90
# 2013-06-03, Close, 35.59
# 2013-06-04, Close, 34.99
# 2013-06-05, Close, 34.78
# 2013-06-06, Close, 34.96
# 2013-06-07, Close, 35.67
# 2013-06-10, Close, 35.47
# 2013-06-11, Close, 34.84
# 2013-06-12, Close, 35.00
# 2013-06-13, Close, 34.72
# 2013-06-14, Close, 34.40
# 2013-06-17, Close, 35.00
# 2013-06-18, Close, 34.98
# 2013-06-19, Close, 34.59
# 2013-06-20, Close, 33.49
# Indicator triggered...entering position
# Exit price 34.62 enter price 33.27
# Exit price will be higher than enter price. Buy!
# 2013-06-21, Close, 33.27
# In position 2 days
# 2013-06-24, Close, 33.72
# In position 3 days
# 2013-06-25, Close, 33.67
# In position 4 days
# 2013-06-26, Close, 34.35
# In position 5 days
# Max days to hold trade reached...closing position
# 2013-06-27, Close, 34.62
# 2013-06-28, Close, 34.54
# 2013-07-01, Close, 34.36
# 2013-07-02, Close, 33.94
# 2013-07-03, Close, 34.01
# 2013-07-05, Close, 34.21
# 2013-07-08, Close, 34.33
# 2013-07-09, Close, 34.35
# 2013-07-10, Close, 34.70
# 2013-07-11, Close, 35.69
# 2013-07-12, Close, 35.67
# 2013-07-15, Close, 36.17
# 2013-07-16, Close, 36.27
# 2013-07-17, Close, 35.74
# 2013-07-18, Close, 35.44
# 2013-07-19, Close, 31.40
# Indicator triggered...entering position
# Exit price 31.62 enter price 32.01
# Exit price will be lower than enter price. Sell!
# 2013-07-22, Close, 32.01
# In position 2 days
# 2013-07-23, Close, 31.82
# In position 3 days
# 2013-07-24, Close, 31.96
# In position 4 days
# 2013-07-25, Close, 31.39
# In position 5 days
# Max days to hold trade reached...closing position
# 2013-07-26, Close, 31.62
# 2013-07-29, Close, 31.54
# 2013-07-30, Close, 31.85
# 2013-07-31, Close, 31.84
# 2013-08-01, Close, 31.67
# 2013-08-02, Close, 31.89
# 2013-08-05, Close, 31.70
# 2013-08-06, Close, 31.58
# 2013-08-07, Close, 32.06
# 2013-08-08, Close, 32.89
# 2013-08-09, Close, 32.70
# 2013-08-12, Close, 32.87
# 2013-08-13, Close, 32.23
# 2013-08-14, Close, 32.35
# 2013-08-15, Close, 31.79
# 2013-08-16, Close, 31.80
# 2013-08-19, Close, 31.39
# 2013-08-20, Close, 31.62
# 2013-08-21, Close, 31.61
# 2013-08-22, Close, 32.39
# 2013-08-23, Close, 34.75
# 2013-08-26, Close, 34.15
# 2013-08-27, Close, 33.26
# 2013-08-28, Close, 33.02
# 2013-08-29, Close, 33.55
# 2013-08-30, Close, 33.40
# 2013-09-03, Close, 31.88
# 2013-09-04, Close, 31.20
# 2013-09-05, Close, 31.23
# 2013-09-06, Close, 31.15
# 2013-09-09, Close, 31.66
# 2013-09-10, Close, 32.39
# 2013-09-11, Close, 32.74
# 2013-09-12, Close, 32.69
# 2013-09-13, Close, 33.03
# 2013-09-16, Close, 32.80
# 2013-09-17, Close, 32.93
# 2013-09-18, Close, 33.32
# 2013-09-19, Close, 33.64
# 2013-09-20, Close, 32.79
# 2013-09-23, Close, 32.74
# 2013-09-24, Close, 32.45
# 2013-09-25, Close, 32.51
# 2013-09-26, Close, 32.77
# 2013-09-27, Close, 33.27
# 2013-09-30, Close, 33.28
# 2013-10-01, Close, 33.58
# 2013-10-02, Close, 33.92
# 2013-10-03, Close, 33.86
# 2013-10-04, Close, 33.88
# 2013-10-07, Close, 33.30
# 2013-10-08, Close, 33.01
# 2013-10-09, Close, 33.07
# 2013-10-10, Close, 33.76
# 2013-10-11, Close, 34.13
# 2013-10-15, Close, 34.49
# 2013-10-16, Close, 34.64
# 2013-10-17, Close, 34.92
# 2013-10-18, Close, 34.96
# 2013-10-21, Close, 34.99
# 2013-10-22, Close, 34.58
# 2013-10-23, Close, 33.76
# 2013-10-24, Close, 33.72
# 2013-10-25, Close, 35.73
# 2013-10-28, Close, 35.57
# 2013-10-29, Close, 35.52
# 2013-10-30, Close, 35.54
# 2013-10-31, Close, 35.41
# 2013-11-01, Close, 35.53
# 2013-11-04, Close, 35.94
# 2013-11-05, Close, 36.64
# 2013-11-06, Close, 38.18
# 2013-11-07, Close, 37.50
# 2013-11-08, Close, 37.78
# 2013-11-12, Close, 37.36
# 2013-11-13, Close, 38.16
# 2013-11-14, Close, 38.02
# 2013-11-15, Close, 37.84
# 2013-11-18, Close, 37.20
# 2013-11-19, Close, 36.74
# 2013-11-20, Close, 37.08
# 2013-11-21, Close, 37.40
# 2013-11-22, Close, 37.57
# 2013-11-25, Close, 37.64
# 2013-11-26, Close, 37.35
# 2013-11-27, Close, 37.60
# 2013-11-29, Close, 38.13
# 2013-12-02, Close, 38.45
# 2013-12-03, Close, 38.31
# 2013-12-04, Close, 38.94
# 2013-12-05, Close, 38.00
# 2013-12-06, Close, 38.36
# 2013-12-09, Close, 38.71
# 2013-12-10, Close, 38.11
# 2013-12-11, Close, 37.61
# 2013-12-12, Close, 37.22
# 2013-12-13, Close, 36.69
# 2013-12-16, Close, 36.89
# 2013-12-17, Close, 36.52
# 2013-12-18, Close, 36.58
# 2013-12-19, Close, 36.25
# 2013-12-20, Close, 36.80
# 2013-12-23, Close, 36.62
# 2013-12-24, Close, 37.08
# 2013-12-26, Close, 37.44
# 2013-12-27, Close, 37.29
# 2013-12-30, Close, 37.29
# 2013-12-31, Close, 37.41
# 2014-01-02, Close, 37.16
# 2014-01-03, Close, 36.91
# 2014-01-06, Close, 36.13
# 2014-01-07, Close, 36.41
# 2014-01-08, Close, 35.76
# Indicator triggered...entering position
# Exit price 36.76 enter price 35.53
# Exit price will be higher than enter price. Buy!
# 2014-01-09, Close, 35.53
# In position 2 days
# 2014-01-10, Close, 36.04
# In position 3 days
# 2014-01-13, Close, 34.98
# In position 4 days
# 2014-01-14, Close, 35.78
# In position 5 days
# Max days to hold trade reached...closing position
# 2014-01-15, Close, 36.76
# 2014-01-16, Close, 36.89
# 2014-01-17, Close, 36.38
# 2014-01-21, Close, 36.17
# 2014-01-22, Close, 35.93
# 2014-01-23, Close, 36.06
# 2014-01-24, Close, 36.81
# 2014-01-27, Close, 36.03
# 2014-01-28, Close, 36.27
# 2014-01-29, Close, 36.66
# 2014-01-30, Close, 36.86
# 2014-01-31, Close, 37.84
# 2014-02-03, Close, 36.48
# 2014-02-04, Close, 36.35
# 2014-02-05, Close, 35.82
# 2014-02-06, Close, 36.18
# 2014-02-07, Close, 36.56
# 2014-02-10, Close, 36.80
# 2014-02-11, Close, 37.17
# 2014-02-12, Close, 37.47
# 2014-02-13, Close, 37.61
# 2014-02-14, Close, 37.62
# 2014-02-18, Close, 37.42
# 2014-02-19, Close, 37.51
# 2014-02-20, Close, 37.75
# 2014-02-21, Close, 37.98
# 2014-02-24, Close, 37.69
# 2014-02-25, Close, 37.54
# 2014-02-26, Close, 37.47
# 2014-02-27, Close, 37.86
# 2014-02-28, Close, 38.31
# 2014-03-03, Close, 37.78
# 2014-03-04, Close, 38.41
# 2014-03-05, Close, 38.11
# 2014-03-06, Close, 38.15
# 2014-03-07, Close, 37.90
# 2014-03-10, Close, 37.82
# 2014-03-11, Close, 38.02
# 2014-03-12, Close, 38.27
# 2014-03-13, Close, 37.89
# 2014-03-14, Close, 37.70
# 2014-03-17, Close, 38.05
# 2014-03-18, Close, 39.55
# 2014-03-19, Close, 39.27
# 2014-03-20, Close, 40.33
# 2014-03-21, Close, 40.16
# 2014-03-24, Close, 40.50
# 2014-03-25, Close, 40.34
# 2014-03-26, Close, 39.79
# 2014-03-27, Close, 39.36
# 2014-03-28, Close, 40.30
# 2014-03-31, Close, 40.99
# 2014-04-01, Close, 41.42
# 2014-04-02, Close, 41.35
# 2014-04-03, Close, 41.01
# 2014-04-04, Close, 39.87
# 2014-04-07, Close, 39.80
# 2014-04-08, Close, 39.82
# 2014-04-09, Close, 40.47
# 2014-04-10, Close, 39.36
# 2014-04-11, Close, 39.21
# 2014-04-14, Close, 39.18
# 2014-04-15, Close, 39.75
# 2014-04-16, Close, 40.40
# 2014-04-17, Close, 40.01
# 2014-04-21, Close, 39.94
# 2014-04-22, Close, 39.99
# 2014-04-23, Close, 39.69
# 2014-04-24, Close, 39.86
# 2014-04-25, Close, 39.91
# 2014-04-28, Close, 40.87
# 2014-04-29, Close, 40.51
# 2014-04-30, Close, 40.40
# 2014-05-01, Close, 40.00
# 2014-05-02, Close, 39.69
# 2014-05-05, Close, 39.43
# 2014-05-06, Close, 39.06
# 2014-05-07, Close, 39.42
# 2014-05-08, Close, 39.64
# 2014-05-09, Close, 39.54
# 2014-05-12, Close, 39.97
# 2014-05-13, Close, 40.42
# 2014-05-14, Close, 40.24
# 2014-05-15, Close, 39.60
# 2014-05-16, Close, 39.83
# 2014-05-19, Close, 39.75
# 2014-05-20, Close, 39.68
# 2014-05-21, Close, 40.35
# 2014-05-22, Close, 40.10
# 2014-05-23, Close, 40.12
# 2014-05-27, Close, 40.19
# 2014-05-28, Close, 40.01
# 2014-05-29, Close, 40.34
# 2014-05-30, Close, 40.94
# 2014-06-02, Close, 40.79
# 2014-06-03, Close, 40.29
# 2014-06-04, Close, 40.32
# 2014-06-05, Close, 41.21
# 2014-06-06, Close, 41.48
# 2014-06-09, Close, 41.27
# 2014-06-10, Close, 41.11
# 2014-06-11, Close, 40.86
# 2014-06-12, Close, 40.58
# 2014-06-13, Close, 41.23
# 2014-06-16, Close, 41.50
# 2014-06-17, Close, 41.68
# 2014-06-18, Close, 41.65
# 2014-06-19, Close, 41.51
# 2014-06-20, Close, 41.68
# 2014-06-23, Close, 41.99
# 2014-06-24, Close, 41.75
# 2014-06-25, Close, 42.03
# 2014-06-26, Close, 41.72
# 2014-06-27, Close, 42.25
# 2014-06-30, Close, 41.70
# 2014-07-01, Close, 41.87
# 2014-07-02, Close, 41.90
# 2014-07-03, Close, 41.80
# 2014-07-07, Close, 41.99
# 2014-07-08, Close, 41.78
# 2014-07-09, Close, 41.67
# 2014-07-10, Close, 41.69
# 2014-07-11, Close, 42.09
# 2014-07-14, Close, 42.14
# 2014-07-15, Close, 42.45
# 2014-07-16, Close, 44.08
# 2014-07-17, Close, 44.53
# 2014-07-18, Close, 44.69
# 2014-07-21, Close, 44.84
# 2014-07-22, Close, 44.83
# 2014-07-23, Close, 44.87
# 2014-07-24, Close, 44.40
# 2014-07-25, Close, 44.50
# 2014-07-28, Close, 43.97
# 2014-07-29, Close, 43.89
# 2014-07-30, Close, 43.58
# 2014-07-31, Close, 43.16
# 2014-08-01, Close, 42.86
# 2014-08-04, Close, 43.37
# 2014-08-05, Close, 43.08
# 2014-08-06, Close, 42.74
# 2014-08-07, Close, 43.23
# 2014-08-08, Close, 43.20
# 2014-08-11, Close, 43.20
# 2014-08-12, Close, 43.52
# 2014-08-13, Close, 44.08
# 2014-08-14, Close, 44.27
# 2014-08-15, Close, 44.79
# 2014-08-18, Close, 45.11
# 2014-08-19, Close, 45.33
# 2014-08-20, Close, 44.95
# 2014-08-21, Close, 45.22
# 2014-08-22, Close, 45.15
# 2014-08-25, Close, 45.17
# 2014-08-26, Close, 45.01
# 2014-08-27, Close, 44.87
# 2014-08-28, Close, 44.88
# 2014-08-29, Close, 45.43
# 2014-09-02, Close, 45.09
# 2014-09-03, Close, 44.96
# 2014-09-04, Close, 45.26
# 2014-09-05, Close, 45.91
# 2014-09-08, Close, 46.47
# 2014-09-09, Close, 46.76
# 2014-09-10, Close, 46.84
# 2014-09-11, Close, 47.00
# 2014-09-12, Close, 46.70
# 2014-09-15, Close, 46.24
# 2014-09-16, Close, 46.76
# 2014-09-17, Close, 46.52
# 2014-09-18, Close, 46.68
# 2014-09-19, Close, 47.52
# 2014-09-24, Close, 47.08
# 2014-09-25, Close, 46.04
# 2014-09-26, Close, 46.41
# 2014-09-29, Close, 46.44
# 2014-09-30, Close, 46.36
# 2014-10-01, Close, 45.90
# 2014-10-02, Close, 45.76
# 2014-10-03, Close, 46.09
# 2014-10-06, Close, 46.09
# 2014-10-07, Close, 45.53
# 2014-10-08, Close, 46.78
# 2014-10-09, Close, 45.85
# 2014-10-10, Close, 44.03
# Indicator triggered...entering position
# Exit price 43.63 enter price 43.65
# Exit price will be lower than enter price. Sell!
# 2014-10-14, Close, 43.73
# In position 2 days
# 2014-10-15, Close, 43.22
# In position 3 days
# 2014-10-16, Close, 42.74
# In position 4 days
# 2014-10-17, Close, 43.63
# In position 5 days
# Max days to hold trade reached...closing position
# 2014-10-20, Close, 44.08
# 2014-10-21, Close, 44.88
# 2014-10-22, Close, 44.38
# 2014-10-23, Close, 45.02
# 2014-10-24, Close, 46.13
# 2014-10-27, Close, 45.91
# 2014-10-28, Close, 46.49
# 2014-10-29, Close, 46.62
# 2014-10-30, Close, 46.05
# 2014-10-31, Close, 46.95
# 2014-11-03, Close, 47.44
# 2014-11-04, Close, 47.57
# 2014-11-05, Close, 47.86
# 2014-11-06, Close, 48.70
# 2014-11-07, Close, 48.68
# 2014-11-10, Close, 48.89
# 2014-11-12, Close, 48.78
# 2014-11-13, Close, 49.61
# 2014-11-14, Close, 49.58
# 2014-11-17, Close, 49.46
# 2014-11-18, Close, 48.74
# 2014-11-19, Close, 48.22
# 2014-11-20, Close, 48.70
# 2014-11-21, Close, 47.98
# 2014-11-24, Close, 47.59
# 2014-11-25, Close, 47.47
# 2014-11-26, Close, 47.75
# 2014-11-28, Close, 47.81
# 2014-12-01, Close, 48.62
# 2014-12-02, Close, 48.46
# 2014-12-03, Close, 48.08
# 2014-12-04, Close, 48.84
# 2014-12-05, Close, 48.42
# 2014-12-08, Close, 47.70
# 2014-12-09, Close, 47.59
# 2014-12-10, Close, 46.90
# 2014-12-11, Close, 47.17
# 2014-12-12, Close, 46.95
# 2014-12-15, Close, 46.67
# 2014-12-16, Close, 45.16
# Indicator triggered...entering position
# Exit price 48.45 enter price 45.74
# Exit price will be higher than enter price. Buy!
# 2014-12-17, Close, 45.74
# In position 2 days
# 2014-12-18, Close, 47.52
# In position 3 days
# 2014-12-19, Close, 47.66
# In position 4 days
# 2014-12-22, Close, 47.98
# In position 5 days
# Max days to hold trade reached...closing position
# 2014-12-23, Close, 48.45
# 2014-12-24, Close, 48.14
# 2014-12-26, Close, 47.88
# 2014-12-29, Close, 47.45
# 2014-12-30, Close, 47.02
# 2014-12-31, Close, 46.45
# 2015-01-02, Close, 46.76
# 2015-01-05, Close, 46.33
# 2015-01-06, Close, 45.65
# 2015-01-07, Close, 46.23
# 2015-01-08, Close, 47.59
# 2015-01-09, Close, 47.19
# 2015-01-12, Close, 46.60
# 2015-01-13, Close, 46.36
# 2015-01-14, Close, 45.96
# 2015-01-15, Close, 45.48
# 2015-01-16, Close, 46.24
# 2015-01-20, Close, 46.39
# 2015-01-21, Close, 45.92
# 2015-01-22, Close, 47.13
# 2015-01-23, Close, 47.18
# 2015-01-26, Close, 47.01
# 2015-01-27, Close, 42.66
# Indicator triggered...entering position
# Exit price 41.60 enter price 41.19
# Exit price will be higher than enter price. Buy!
# 2015-01-28, Close, 41.19
# In position 2 days
# 2015-01-29, Close, 42.01
# In position 3 days
# 2015-01-30, Close, 40.40
# In position 4 days
# 2015-02-02, Close, 41.28
# In position 5 days
# Max days to hold trade reached...closing position
# 2015-02-03, Close, 41.60
# 2015-02-04, Close, 41.84
# 2015-02-05, Close, 42.45
# 2015-02-06, Close, 42.41
# 2015-02-09, Close, 42.36
# 2015-02-10, Close, 42.60
# 2015-02-11, Close, 42.38
# 2015-02-12, Close, 43.09
# 2015-02-13, Close, 43.87
# 2015-02-17, Close, 43.58
# 2015-02-18, Close, 43.53
# 2015-02-19, Close, 43.50
# 2015-02-20, Close, 43.86
# 2015-02-23, Close, 44.15
# 2015-02-24, Close, 44.09
# 2015-02-25, Close, 43.99
# 2015-02-26, Close, 44.06
# 2015-03-02, Close, 43.88
# 2015-03-03, Close, 43.28
# 2015-03-04, Close, 43.06
# 2015-03-05, Close, 43.11
# 2015-03-06, Close, 42.36
# 2015-03-09, Close, 42.85
# 2015-03-10, Close, 42.03
# 2015-03-11, Close, 41.98
# 2015-03-12, Close, 41.02
# Indicator triggered...entering position
# Exit price 42.29 enter price 41.38
# Exit price will be higher than enter price. Buy!
# 2015-03-13, Close, 41.38
# In position 2 days
# 2015-03-16, Close, 41.56
# In position 3 days
# 2015-03-17, Close, 41.70
# In position 4 days
# 2015-03-18, Close, 42.50
# In position 5 days
# Max days to hold trade reached...closing position
# 2015-03-19, Close, 42.29
# 2015-03-20, Close, 42.88
# 2015-03-23, Close, 42.86
# 2015-03-24, Close, 42.90
# 2015-03-25, Close, 41.46
# 2015-03-26, Close, 41.21
# 2015-03-27, Close, 40.97
# 2015-03-30, Close, 40.96
# 2015-03-31, Close, 40.66
# 2015-04-01, Close, 40.72
# 2015-04-02, Close, 40.29
# 2015-04-06, Close, 41.55
# 2015-04-07, Close, 41.53
# 2015-04-08, Close, 41.42
# 2015-04-09, Close, 41.48
# 2015-04-10, Close, 41.72
# 2015-04-13, Close, 41.76
# 2015-04-14, Close, 41.65
# 2015-04-15, Close, 42.26
# 2015-04-16, Close, 42.16
# 2015-04-17, Close, 41.62
# 2015-04-20, Close, 42.91
# 2015-04-21, Close, 42.64
# 2015-04-22, Close, 42.99
# 2015-04-23, Close, 43.34
# 2015-04-24, Close, 47.87
# 2015-04-27, Close, 48.03
# 2015-04-28, Close, 49.16
# 2015-04-29, Close, 49.06
# 2015-04-30, Close, 48.64
# 2015-05-01, Close, 48.66
# 2015-05-04, Close, 48.24
# 2015-05-05, Close, 47.60
# 2015-05-06, Close, 46.28
# 2015-05-07, Close, 46.70
# 2015-05-08, Close, 47.75
# 2015-05-11, Close, 47.37
# 2015-05-12, Close, 47.35
# 2015-05-13, Close, 47.63
# 2015-05-14, Close, 48.72
# 2015-05-15, Close, 48.30
# 2015-05-18, Close, 48.01
# 2015-05-19, Close, 47.58
# 2015-05-20, Close, 47.58
# 2015-05-21, Close, 47.42
# 2015-05-22, Close, 46.90
# 2015-05-26, Close, 46.59
# 2015-05-27, Close, 47.61
# 2015-05-28, Close, 47.45
# 2015-05-29, Close, 46.86
# 2015-06-01, Close, 47.23
# 2015-06-02, Close, 46.92
# 2015-06-03, Close, 46.85
# 2015-06-04, Close, 46.36
# 2015-06-05, Close, 46.14
# 2015-06-08, Close, 45.73
# Indicator triggered...entering position
# Exit price 45.48 enter price 45.65
# Exit price will be lower than enter price. Sell!
# 2015-06-09, Close, 45.65
# In position 2 days
# 2015-06-10, Close, 46.61
# In position 3 days
# 2015-06-11, Close, 46.44
# In position 4 days
# 2015-06-12, Close, 45.97
# In position 5 days
# Max days to hold trade reached...closing position
# 2015-06-15, Close, 45.48
# 2015-06-16, Close, 45.83
# 2015-06-17, Close, 45.97
# 2015-06-18, Close, 46.72
# 2015-06-19, Close, 46.10
# 2015-06-22, Close, 46.23
# 2015-06-23, Close, 45.91
# 2015-06-24, Close, 45.64
# 2015-06-25, Close, 45.65
# 2015-06-26, Close, 45.26
# 2015-06-29, Close, 44.37
# Indicator triggered...entering position
# Exit price 44.30 enter price 44.15
# Exit price will be higher than enter price. Buy!
# 2015-06-30, Close, 44.15
# In position 2 days
# 2015-07-01, Close, 44.45
# In position 3 days
# 2015-07-02, Close, 44.40
# In position 4 days
# 2015-07-06, Close, 44.39
# In position 5 days
# Max days to hold trade reached...closing position
# 2015-07-07, Close, 44.30
# 2015-07-08, Close, 44.24
# 2015-07-09, Close, 44.52
# 2015-07-10, Close, 44.61
# 2015-07-13, Close, 45.54
# 2015-07-14, Close, 45.62
# 2015-07-15, Close, 45.76
# 2015-07-16, Close, 46.66
# 2015-07-17, Close, 46.62
# 2015-07-20, Close, 46.92
# 2015-07-21, Close, 47.28
# 2015-07-22, Close, 45.54
# 2015-07-23, Close, 46.11
# 2015-07-24, Close, 45.94
# 2015-07-27, Close, 45.35
# 2015-07-28, Close, 45.34
# 2015-07-29, Close, 46.29
# 2015-07-30, Close, 46.88
# 2015-07-31, Close, 46.70
# 2015-08-04, Close, 47.54
# 2015-08-06, Close, 46.62
# 2015-08-07, Close, 46.74
# 2015-08-10, Close, 47.33
# 2015-08-11, Close, 46.41
# 2015-08-12, Close, 46.74
# 2015-08-13, Close, 46.73
# 2015-08-14, Close, 47.00
# 2015-08-17, Close, 47.32
# 2015-08-18, Close, 47.27
# 2015-08-19, Close, 46.61
# 2015-08-20, Close, 45.66
# 2015-08-21, Close, 43.07
# Indicator triggered...entering position
# Exit price 43.93 enter price 41.68
# Exit price will be higher than enter price. Buy!
# 2015-08-24, Close, 41.68
# In position 2 days
# 2015-08-25, Close, 40.47
# In position 3 days
# 2015-08-26, Close, 42.71
# In position 4 days
# 2015-08-27, Close, 43.90
# In position 5 days
# Max days to hold trade reached...closing position
# 2015-08-28, Close, 43.93
# 2015-08-31, Close, 43.52
# 2015-09-01, Close, 41.82
# 2015-09-02, Close, 43.36
# 2015-09-03, Close, 43.50
# 2015-09-04, Close, 42.61
# 2015-09-08, Close, 43.89
# 2015-09-09, Close, 43.07
# 2015-09-10, Close, 43.29
# 2015-09-11, Close, 43.48
# 2015-09-14, Close, 43.04
# 2015-09-15, Close, 43.98
# 2015-09-16, Close, 44.30
# 2015-09-17, Close, 44.25
# 2015-09-18, Close, 43.48
# 2015-09-21, Close, 44.11
# 2015-09-22, Close, 43.90
# 2015-09-23, Close, 43.87
# 2015-09-24, Close, 43.91
# 2015-09-25, Close, 43.94
# 2015-09-29, Close, 43.44
# 2015-09-30, Close, 44.26
# 2015-10-01, Close, 44.61
# 2015-10-02, Close, 45.57
# 2015-10-05, Close, 46.63
# 2015-10-06, Close, 46.75
# 2015-10-07, Close, 46.80
# 2015-10-08, Close, 47.45
# 2015-10-09, Close, 47.11
# 2015-10-13, Close, 46.89
# 2015-10-14, Close, 46.68
# 2015-10-15, Close, 47.01
# 2015-10-16, Close, 47.51
# 2015-10-19, Close, 47.62
# 2015-10-20, Close, 47.77
# 2015-10-21, Close, 47.20
# 2015-10-22, Close, 48.03
# 2015-10-23, Close, 52.87
# 2015-10-26, Close, 54.25
# 2015-10-27, Close, 53.69
# 2015-10-28, Close, 53.98
# 2015-10-29, Close, 53.36
# 2015-10-30, Close, 52.64
# 2015-11-02, Close, 53.24
# 2015-11-03, Close, 54.15
# 2015-11-04, Close, 54.40
# 2015-11-05, Close, 54.38
# 2015-11-06, Close, 54.92
# 2015-11-09, Close, 54.16
# 2015-11-10, Close, 53.51
# 2015-11-12, Close, 53.32
# 2015-11-13, Close, 52.84
# 2015-11-16, Close, 53.77
# 2015-11-17, Close, 52.97
# 2015-11-18, Close, 53.85
# 2015-11-19, Close, 53.94
# 2015-11-20, Close, 54.19
# 2015-11-23, Close, 54.19
# 2015-11-24, Close, 54.25
# 2015-11-25, Close, 53.69
# 2015-11-27, Close, 53.93
# 2015-11-30, Close, 54.35
# 2015-12-01, Close, 55.22
# 2015-12-02, Close, 55.21
# 2015-12-03, Close, 54.20
# 2015-12-04, Close, 55.91
# 2015-12-07, Close, 55.81
# 2015-12-08, Close, 55.79
# 2015-12-09, Close, 54.98
# 2015-12-10, Close, 55.27
# 2015-12-11, Close, 54.06
# 2015-12-14, Close, 55.14
# 2015-12-15, Close, 55.20
# 2015-12-16, Close, 56.13
# 2015-12-17, Close, 55.70
# 2015-12-18, Close, 54.13
# 2015-12-21, Close, 54.83
# 2015-12-23, Close, 55.82
# 2015-12-24, Close, 55.67
# 2015-12-28, Close, 55.95
# 2015-12-29, Close, 56.55
# 2015-12-30, Close, 56.31
# 2015-12-31, Close, 55.48
# 2016-01-04, Close, 54.80
# 2016-01-05, Close, 55.05
# 2016-01-06, Close, 54.05
# 2016-01-07, Close, 52.17
# Indicator triggered...entering position
# Exit price 53.11 enter price 52.33
# Exit price will be higher than enter price. Buy!
# 2016-01-08, Close, 52.33
# In position 2 days
# 2016-01-11, Close, 52.30
# In position 3 days
# 2016-01-12, Close, 52.78
# In position 4 days
# 2016-01-13, Close, 51.64
# In position 5 days
# Max days to hold trade reached...closing position
# 2016-01-14, Close, 53.11
# 2016-01-15, Close, 50.99
# 2016-01-19, Close, 50.56
# 2016-01-20, Close, 50.79
# 2016-01-21, Close, 50.48
# 2016-01-22, Close, 52.29
# 2016-01-25, Close, 51.79
# 2016-01-26, Close, 52.17
# 2016-01-27, Close, 51.22
# 2016-01-28, Close, 52.06
# 2016-01-29, Close, 55.09
# 2016-02-01, Close, 54.71
# 2016-02-02, Close, 53.00
# 2016-02-03, Close, 52.16
# 2016-02-04, Close, 52.00
# 2016-02-05, Close, 50.16
# 2016-02-08, Close, 49.41
# 2016-02-09, Close, 49.28
# 2016-02-10, Close, 49.71
# 2016-02-11, Close, 49.69
# 2016-02-12, Close, 50.50
# 2016-02-16, Close, 51.09
# 2016-02-17, Close, 52.42
# 2016-02-18, Close, 52.19
# 2016-02-19, Close, 51.82
# 2016-02-23, Close, 51.18
# 2016-02-24, Close, 51.36
# 2016-02-25, Close, 52.10
# 2016-02-26, Close, 51.30
# 2016-03-01, Close, 52.58
# 2016-03-02, Close, 52.95
# 2016-03-03, Close, 52.35
# 2016-03-04, Close, 52.03
# 2016-03-07, Close, 51.03
# 2016-03-08, Close, 51.65
# 2016-03-09, Close, 52.84
# 2016-03-10, Close, 52.05
# 2016-03-11, Close, 53.07
# 2016-03-14, Close, 53.17
# 2016-03-15, Close, 53.59
# 2016-03-16, Close, 54.35
# 2016-03-17, Close, 54.66
# 2016-03-18, Close, 53.49
# 2016-03-21, Close, 53.86
# 2016-03-22, Close, 54.07
# 2016-03-23, Close, 53.97
# 2016-03-24, Close, 54.21
# 2016-03-28, Close, 53.54
# 2016-03-29, Close, 54.71
# 2016-03-30, Close, 55.05
# 2016-03-31, Close, 55.23
# 2016-04-01, Close, 55.57
# 2016-04-04, Close, 55.43
# 2016-04-05, Close, 54.56
# 2016-04-06, Close, 55.12
# 2016-04-07, Close, 54.46
# 2016-04-08, Close, 54.42
# 2016-04-11, Close, 54.31
# 2016-04-12, Close, 54.65
# 2016-04-13, Close, 55.35
# 2016-04-14, Close, 55.36
# 2016-04-15, Close, 55.65
# 2016-04-18, Close, 56.46
# 2016-04-19, Close, 56.39
# 2016-04-20, Close, 55.59
# 2016-04-21, Close, 55.78
# 2016-04-22, Close, 51.78
# Indicator triggered...entering position
# Exit price 49.87 enter price 52.11
# Exit price will be lower than enter price. Sell!
# 2016-04-25, Close, 52.11
# In position 2 days
# 2016-04-26, Close, 51.44
# In position 3 days
# 2016-04-27, Close, 50.94
# In position 4 days
# 2016-04-28, Close, 49.90
# In position 5 days
# Max days to hold trade reached...closing position
# 2016-04-29, Close, 49.87
# 2016-05-02, Close, 50.61
# 2016-05-03, Close, 49.78
# 2016-05-04, Close, 49.87
# 2016-05-05, Close, 49.94
# 2016-05-06, Close, 50.39
# 2016-05-09, Close, 50.07
# 2016-05-10, Close, 51.02
# 2016-05-11, Close, 51.05
# 2016-05-12, Close, 51.51
# 2016-05-13, Close, 51.08
# 2016-05-16, Close, 51.83
# 2016-05-17, Close, 50.51
# 2016-05-18, Close, 50.81
# 2016-05-19, Close, 50.32
# 2016-05-20, Close, 50.62
# 2016-05-23, Close, 50.03
# 2016-05-24, Close, 51.59
# 2016-05-25, Close, 52.12
# 2016-05-26, Close, 51.89
# 2016-05-27, Close, 52.32
# 2016-05-31, Close, 53.00
# 2016-06-01, Close, 52.85
# 2016-06-02, Close, 52.48
# 2016-06-03, Close, 51.79
# 2016-06-06, Close, 52.13
# 2016-06-07, Close, 52.10
# 2016-06-08, Close, 52.04
# 2016-06-09, Close, 51.62
# 2016-06-10, Close, 51.48
# 2016-06-13, Close, 50.14
# 2016-06-14, Close, 49.83
# 2016-06-15, Close, 49.69
# 2016-06-16, Close, 50.39
# 2016-06-17, Close, 50.13
# 2016-06-20, Close, 50.07
# 2016-06-21, Close, 51.19
# 2016-06-22, Close, 50.99
# 2016-06-23, Close, 51.91
# 2016-06-24, Close, 49.83
# 2016-06-27, Close, 48.43
# Indicator triggered...entering position
# Exit price 51.17 enter price 49.44
# Exit price will be higher than enter price. Buy!
# 2016-06-28, Close, 49.44
# In position 2 days
# 2016-06-29, Close, 50.54
# In position 3 days
# 2016-06-30, Close, 51.17
# In position 4 days
# 2016-07-01, Close, 51.16
# In position 5 days
# Max days to hold trade reached...closing position
# 2016-07-05, Close, 51.17
# 2016-07-06, Close, 51.38
# 2016-07-07, Close, 51.38
# 2016-07-08, Close, 52.30
# 2016-07-11, Close, 52.59
# 2016-07-12, Close, 53.21
# 2016-07-13, Close, 53.51
# 2016-07-14, Close, 53.74
# 2016-07-15, Close, 53.70
# 2016-07-18, Close, 53.96
# 2016-07-19, Close, 53.09
# 2016-07-20, Close, 55.91
# 2016-07-21, Close, 55.80
# 2016-07-22, Close, 56.57
# 2016-07-25, Close, 56.73
# 2016-07-26, Close, 56.76
# 2016-07-27, Close, 56.19
# 2016-07-28, Close, 56.21
# 2016-07-29, Close, 56.68
# 2016-08-01, Close, 56.58
# 2016-08-02, Close, 56.58
# 2016-08-03, Close, 56.97
# 2016-08-04, Close, 57.39
# 2016-08-05, Close, 57.96
# 2016-08-08, Close, 58.06
# 2016-08-09, Close, 58.20
# 2016-08-10, Close, 58.02
# 2016-08-11, Close, 58.30
# 2016-08-12, Close, 57.94
# 2016-08-15, Close, 58.12
# 2016-08-16, Close, 57.44
# 2016-08-17, Close, 57.56
# 2016-08-18, Close, 57.60
# 2016-08-19, Close, 57.62
# 2016-08-22, Close, 57.67
# 2016-08-23, Close, 57.89
# 2016-08-24, Close, 57.95
# 2016-08-25, Close, 58.17
# 2016-08-26, Close, 58.03
# 2016-08-29, Close, 58.10
# 2016-08-30, Close, 57.89
# 2016-08-31, Close, 57.46
# 2016-09-01, Close, 57.59
# 2016-09-06, Close, 57.61
# 2016-09-07, Close, 57.66
# 2016-09-08, Close, 57.43
# 2016-09-09, Close, 56.21
# Indicator triggered...entering position
# Exit price 57.25 enter price 57.05
# Exit price will be higher than enter price. Buy!
# 2016-09-12, Close, 57.05
# In position 2 days
# 2016-09-13, Close, 56.53
# In position 3 days
# 2016-09-14, Close, 56.26
# In position 4 days
# 2016-09-15, Close, 57.19
# In position 5 days
# Max days to hold trade reached...closing position
# 2016-09-16, Close, 57.25
# 2016-09-19, Close, 56.93
# 2016-09-20, Close, 56.81
# 2016-09-21, Close, 57.76
# 2016-09-22, Close, 57.82
# 2016-09-23, Close, 57.43
# 2016-09-26, Close, 56.90
# 2016-09-27, Close, 57.95
# 2016-09-28, Close, 58.03
# 2016-09-29, Close, 57.40
# 2016-09-30, Close, 57.60
# 2016-10-03, Close, 57.42
# 2016-10-04, Close, 57.24
# 2016-10-05, Close, 57.64
# 2016-10-06, Close, 57.74
# 2016-10-07, Close, 57.80
# 2016-10-11, Close, 57.19
# 2016-10-12, Close, 57.11
# 2016-10-13, Close, 56.92
# 2016-10-14, Close, 57.42
# 2016-10-17, Close, 57.22
# 2016-10-18, Close, 57.66
# 2016-10-19, Close, 57.53
# 2016-10-20, Close, 57.25
# 2016-10-21, Close, 59.66
# 2016-10-24, Close, 61.00
# 2016-10-25, Close, 60.99
# 2016-10-26, Close, 60.63
# 2016-10-27, Close, 60.10
# 2016-10-28, Close, 59.87
# 2016-10-31, Close, 59.92
# 2016-11-01, Close, 59.80
# 2016-11-02, Close, 59.43
# 2016-11-03, Close, 59.21
# 2016-11-04, Close, 58.71
# 2016-11-07, Close, 60.42
# 2016-11-08, Close, 60.47
# 2016-11-09, Close, 60.17
# 2016-11-10, Close, 58.70
# 2016-11-14, Close, 58.12
# 2016-11-15, Close, 58.87
# 2016-11-16, Close, 59.65
# 2016-11-17, Close, 60.64
# 2016-11-18, Close, 60.35
# 2016-11-21, Close, 60.86
# 2016-11-22, Close, 61.12
# 2016-11-23, Close, 60.40
# 2016-11-25, Close, 60.53
# 2016-11-28, Close, 60.61
# 2016-11-29, Close, 61.09
# 2016-11-30, Close, 60.26
# 2016-12-01, Close, 59.20
# 2016-12-02, Close, 59.25
# 2016-12-05, Close, 60.22
# 2016-12-06, Close, 59.95
# 2016-12-07, Close, 61.37
# 2016-12-08, Close, 61.01
# 2016-12-09, Close, 61.97
# 2016-12-12, Close, 62.17
# 2016-12-13, Close, 62.98
# 2016-12-14, Close, 62.68
# 2016-12-15, Close, 62.58
# 2016-12-16, Close, 62.30
# 2016-12-19, Close, 63.62
# 2016-12-20, Close, 63.54
# 2016-12-21, Close, 63.54
# 2016-12-22, Close, 63.55
# 2016-12-23, Close, 63.24
# 2016-12-27, Close, 63.28
# 2016-12-28, Close, 62.99
# 2016-12-29, Close, 62.90
# 2016-12-30, Close, 62.14
# 2017-01-03, Close, 62.58
# 2017-01-04, Close, 62.30
# 2017-01-05, Close, 62.30
# 2017-01-06, Close, 62.84
# 2017-01-09, Close, 62.64
# 2017-01-10, Close, 62.62
# 2017-01-11, Close, 63.19
# 2017-01-12, Close, 62.61
# 2017-01-13, Close, 62.70
# 2017-01-17, Close, 62.53
# 2017-01-18, Close, 62.50
# 2017-01-19, Close, 62.30
# 2017-01-20, Close, 62.74
# 2017-01-23, Close, 62.96
# 2017-01-24, Close, 63.52
# 2017-01-25, Close, 63.68
# 2017-01-26, Close, 64.27
# 2017-01-27, Close, 65.78
# 2017-01-30, Close, 65.13
# 2017-01-31, Close, 64.65
# 2017-02-01, Close, 63.58
# 2017-02-02, Close, 63.17
# 2017-02-03, Close, 63.68
# 2017-02-06, Close, 63.64
# 2017-02-07, Close, 63.43
# 2017-02-08, Close, 63.34
# 2017-02-09, Close, 64.06
# 2017-02-10, Close, 64.00
# 2017-02-13, Close, 64.72
# 2017-02-14, Close, 64.57
# 2017-02-15, Close, 64.53
# 2017-02-16, Close, 64.52
# 2017-02-17, Close, 64.62
# 2017-02-21, Close, 64.49
# 2017-02-22, Close, 64.36
# 2017-02-23, Close, 64.62
# 2017-02-24, Close, 64.62
# 2017-02-27, Close, 64.23
# 2017-02-28, Close, 63.98
# 2017-03-01, Close, 64.94
# 2017-03-02, Close, 64.01
# 2017-03-03, Close, 64.25
# 2017-03-06, Close, 64.27
# 2017-03-07, Close, 64.40
# 2017-03-08, Close, 64.99
# 2017-03-09, Close, 64.73
# 2017-03-10, Close, 64.93
# 2017-03-13, Close, 64.71
# 2017-03-14, Close, 64.41
# 2017-03-15, Close, 64.75
# 2017-03-16, Close, 64.64
# 2017-03-17, Close, 64.87
# 2017-03-20, Close, 64.93
# 2017-03-21, Close, 64.21
# 2017-03-22, Close, 65.03
# 2017-03-23, Close, 64.87
# 2017-03-24, Close, 64.98
# 2017-03-27, Close, 65.10
# 2017-03-28, Close, 65.29
# 2017-03-29, Close, 65.47
# 2017-03-30, Close, 65.71
# 2017-03-31, Close, 65.86
# 2017-04-03, Close, 65.55
# 2017-04-04, Close, 65.73
# 2017-04-05, Close, 65.56
# 2017-04-06, Close, 65.73
# 2017-04-07, Close, 65.68
# 2017-04-10, Close, 65.53
# 2017-04-11, Close, 65.48
# 2017-04-12, Close, 65.23
# 2017-04-13, Close, 64.95
# 2017-04-17, Close, 65.48
# 2017-04-18, Close, 65.39
# 2017-04-19, Close, 65.04
# 2017-04-20, Close, 65.50
# 2017-04-21, Close, 66.40
# 2017-04-24, Close, 67.53
# 2017-04-25, Close, 67.92
# 2017-04-26, Close, 67.83
# 2017-04-27, Close, 68.27
# 2017-04-28, Close, 68.46
# 2017-05-01, Close, 69.41
# 2017-05-02, Close, 69.30
# 2017-05-03, Close, 69.08
# 2017-05-04, Close, 68.81
# 2017-05-05, Close, 69.00
# 2017-05-08, Close, 68.94
# 2017-05-09, Close, 69.04
# 2017-05-10, Close, 69.31
# 2017-05-11, Close, 68.46
# 2017-05-12, Close, 68.38
# 2017-05-15, Close, 68.43
# 2017-05-16, Close, 69.41
# 2017-05-17, Close, 67.48
# 2017-05-18, Close, 67.71
# 2017-05-19, Close, 67.69
# 2017-05-22, Close, 68.45
# 2017-05-23, Close, 68.68
# 2017-05-24, Close, 68.77
# 2017-05-25, Close, 69.62
# 2017-05-26, Close, 69.96
# 2017-05-30, Close, 70.41
# 2017-05-31, Close, 69.84
# 2017-06-01, Close, 70.10
# 2017-06-02, Close, 71.76
# 2017-06-05, Close, 72.28
# 2017-06-06, Close, 72.52
# 2017-06-07, Close, 72.39
# 2017-06-08, Close, 71.95
# 2017-06-09, Close, 70.32
# 2017-06-12, Close, 69.78
# 2017-06-13, Close, 70.65
# 2017-06-14, Close, 70.27
# 2017-06-15, Close, 69.90
# 2017-06-16, Close, 70.00
# 2017-06-19, Close, 70.87
# 2017-06-20, Close, 69.91
# 2017-06-21, Close, 70.27
# 2017-06-22, Close, 70.26
# 2017-06-23, Close, 71.21
# 2017-06-26, Close, 70.53
# 2017-06-27, Close, 69.21
# 2017-06-28, Close, 69.80
# 2017-06-29, Close, 68.49
# 2017-06-30, Close, 68.93
# 2017-07-03, Close, 68.17
# 2017-07-05, Close, 69.08
# 2017-07-06, Close, 68.57
# 2017-07-07, Close, 69.46
# 2017-07-10, Close, 69.98
# 2017-07-11, Close, 69.99
# 2017-07-12, Close, 71.15
# 2017-07-13, Close, 71.77
# 2017-07-14, Close, 72.78
# 2017-07-17, Close, 73.35
# 2017-07-18, Close, 73.30
# 2017-07-19, Close, 73.86
# 2017-07-20, Close, 74.22
# 2017-07-21, Close, 73.79
# 2017-07-24, Close, 73.60
# 2017-07-25, Close, 74.19
# 2017-07-26, Close, 74.05
# 2017-07-27, Close, 73.16
# 2017-07-28, Close, 73.04
# 2017-07-31, Close, 72.70
# 2017-08-01, Close, 72.58
# 2017-08-02, Close, 72.26
# 2017-08-03, Close, 72.15
# 2017-08-04, Close, 72.68
# 2017-08-07, Close, 72.40
# 2017-08-08, Close, 72.79
# 2017-08-09, Close, 72.47
# 2017-08-10, Close, 71.41
# Indicator triggered...entering position
# Exit price 72.40 enter price 72.50
# Exit price will be lower than enter price. Sell!
# 2017-08-11, Close, 72.50
# In position 2 days
# 2017-08-14, Close, 73.59
# In position 3 days
# 2017-08-15, Close, 73.22
# In position 4 days
# 2017-08-16, Close, 73.65
# In position 5 days
# Max days to hold trade reached...closing position
# 2017-08-17, Close, 72.40
# 2017-08-18, Close, 72.49
# 2017-08-21, Close, 72.15
# 2017-08-22, Close, 73.16
# 2017-08-23, Close, 72.72
# 2017-08-24, Close, 72.69
# 2017-08-25, Close, 72.82
# 2017-08-28, Close, 72.83
# 2017-08-29, Close, 73.05
# 2017-08-30, Close, 74.01
# 2017-08-31, Close, 74.77
# 2017-09-01, Close, 73.94
# 2017-09-05, Close, 73.61
# 2017-09-06, Close, 73.40
# 2017-09-07, Close, 74.34
# 2017-09-08, Close, 73.98
# 2017-09-11, Close, 74.76
# 2017-09-12, Close, 74.68
# 2017-09-13, Close, 75.21
# 2017-09-14, Close, 74.77
# 2017-09-15, Close, 75.31
# 2017-09-18, Close, 75.16
# 2017-09-19, Close, 75.44
# 2017-09-20, Close, 74.94
# 2017-09-21, Close, 74.21
# 2017-09-22, Close, 74.41
# 2017-09-25, Close, 73.26
# 2017-09-26, Close, 73.26
# 2017-09-27, Close, 73.85
# 2017-09-28, Close, 73.87
# 2017-09-29, Close, 74.49
# 2017-10-02, Close, 74.61
# 2017-10-03, Close, 74.26
# 2017-10-04, Close, 74.69
# 2017-10-05, Close, 75.97
# 2017-10-06, Close, 76.00
# 2017-10-10, Close, 76.29
# 2017-10-11, Close, 76.42
# 2017-10-12, Close, 77.12
# 2017-10-13, Close, 77.49
# 2017-10-16, Close, 77.65
# 2017-10-17, Close, 77.59
# 2017-10-18, Close, 77.61
# 2017-10-19, Close, 77.91
# 2017-10-20, Close, 78.81
# 2017-10-23, Close, 78.83
# 2017-10-24, Close, 78.86
# 2017-10-25, Close, 78.63
# 2017-10-26, Close, 78.76
# 2017-10-27, Close, 83.81
# 2017-10-30, Close, 83.89
# 2017-10-31, Close, 83.18
# 2017-11-01, Close, 83.18
# 2017-11-02, Close, 84.05
# 2017-11-03, Close, 84.14
# 2017-11-06, Close, 84.47
# 2017-11-07, Close, 84.27
# 2017-11-08, Close, 84.56
# 2017-11-09, Close, 84.09
# 2017-11-10, Close, 83.87
# 2017-11-13, Close, 83.93
# 2017-11-14, Close, 84.05
# 2017-11-15, Close, 82.98
# 2017-11-16, Close, 83.20
# 2017-11-17, Close, 82.40
# 2017-11-20, Close, 82.53
# 2017-11-21, Close, 83.72
# 2017-11-22, Close, 83.11
# 2017-11-24, Close, 83.26
# 2017-11-27, Close, 83.87
# 2017-11-28, Close, 84.88
# 2017-11-29, Close, 83.34
# 2017-11-30, Close, 84.17
# 2017-12-01, Close, 84.26
# 2017-12-04, Close, 81.08
# Indicator triggered...entering position
# Exit price 85.23 enter price 81.59
# Exit price will be higher than enter price. Buy!
# 2017-12-05, Close, 81.59
# In position 2 days
# 2017-12-06, Close, 82.78
# In position 3 days
# 2017-12-07, Close, 82.49
# In position 4 days
# 2017-12-08, Close, 84.16
# In position 5 days
# Max days to hold trade reached...closing position
# 2017-12-11, Close, 85.23
# 2017-12-12, Close, 85.58
# 2017-12-13, Close, 85.35
# 2017-12-14, Close, 84.69
# 2017-12-15, Close, 86.85
# 2017-12-18, Close, 86.38
# 2017-12-19, Close, 85.83
# 2017-12-20, Close, 85.52
# 2017-12-21, Close, 85.50
# 2017-12-22, Close, 85.51
# 2017-12-26, Close, 85.40
# 2017-12-27, Close, 85.71
# 2017-12-28, Close, 85.72
# 2017-12-29, Close, 85.54
# 2018-01-02, Close, 85.95
# 2018-01-03, Close, 86.35
# 2018-01-04, Close, 87.11
# 2018-01-05, Close, 88.19
# 2018-01-08, Close, 88.28
# 2018-01-09, Close, 88.22
# 2018-01-10, Close, 87.82
# 2018-01-11, Close, 88.08
# 2018-01-12, Close, 89.60
# 2018-01-16, Close, 88.35
# 2018-01-17, Close, 90.14
# 2018-01-18, Close, 90.10
# 2018-01-19, Close, 90.00
# 2018-01-22, Close, 91.61
# 2018-01-23, Close, 91.90
# 2018-01-24, Close, 91.82
# 2018-01-25, Close, 92.33
# 2018-01-26, Close, 94.06
# 2018-01-29, Close, 93.92
# 2018-01-30, Close, 92.74
# 2018-01-31, Close, 95.01
# 2018-02-01, Close, 94.26
# 2018-02-02, Close, 91.78
# 2018-02-05, Close, 88.00
# 2018-02-06, Close, 91.33
# 2018-02-07, Close, 89.61
# 2018-02-08, Close, 85.01
# Indicator triggered...entering position
# Exit price 92.66 enter price 88.18
# Exit price will be higher than enter price. Buy!
# 2018-02-09, Close, 88.18
# In position 2 days
# 2018-02-12, Close, 89.13
# In position 3 days
# 2018-02-13, Close, 89.83
# In position 4 days
# 2018-02-14, Close, 90.81
# In position 5 days
# Max days to hold trade reached...closing position
# 2018-02-15, Close, 92.66
# 2018-02-16, Close, 92.00
# 2018-02-20, Close, 92.72
# 2018-02-21, Close, 91.49
# 2018-02-22, Close, 91.73
# 2018-02-23, Close, 94.06
# 2018-02-26, Close, 95.42
# 2018-02-27, Close, 94.20
# 2018-02-28, Close, 93.77
# Final Portfolio Value: 100033.28
