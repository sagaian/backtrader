# %% [markdown]
# # Backtesting the HMM Model

# %% [markdown]
# Signals are identifed by the hmm model and imported into the system.
#
#     When signal = 1, we enter the mean reversion position.
#     When signal = 0, we enter the momentum position.
#
#
# Mean Reversion Strategy:
#
#      1.We rank the returns of ETF stocks in the past month
#      2.For bottom 3 stock, we buy
#      3.For top 3 stocks, we sell
#      4.We close the position every 10 days
#
#
# Momentum Strategy:
#
#      1.We rank the returns of ETF stocks in the past 6 months
#      2.For bottom 3 stock, we buy
#      3.For top 3 stocks, we sell
#      4.We close the position every month

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt

import pandas as pd
from datetime import datetime
import backtrader.analyzers as btanalyzers
import matplotlib.pyplot as plt

# %%
class RSI_Oversold(bt.Indicator):
    lines = ('oversold',)
    
    params = (
        ('level', 30),    
    )

    def __init__(self):
        self.lines.oversold = bt.indicators.RSI(self.data) < self.p.level

        
class DummyInd(bt.Indicator):
    lines = ('dummyline',)

    params = (('value', 5),)

    def __init__(self):
        self.lines.dummyline = bt.Max(0.0, self.params.value)

        
# Create a Stratey
class BackTradingStrategy(bt.Strategy):
    params = (
        ('period', 255),
        ("max_days_in_trade", 10)
    )

    def log(self, txt, txt2, txt3, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s, %s, %s' % (dt.isoformat(), txt, txt2, txt3))
        
        
    def read_signals(self):
        signal_data = pd.read_csv("hmm_regime_signals.csv")
        signal_data["datetime"] = signal_data["datetime"].apply(lambda x: datetime.strptime(x,"%m/%d/%Y"))
        signal_data = signal_data.set_index('datetime')
        
        return signal_data
    
    
        

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        # How to access individual etf
        self.xlb_close = self.datas[symbols.index("XLB")].close
        self.xle_close = self.datas[symbols.index("XLE")].close
        self.xlf_close = self.datas[symbols.index("XLF")].close
        self.xli_close = self.datas[symbols.index("XLI")].close
        self.xlk_close = self.datas[symbols.index("XLK")].close
        self.xlp_close = self.datas[symbols.index("XLP")].close
        self.xlu_close = self.datas[symbols.index("XLU")].close
        self.xlv_close = self.datas[symbols.index("XLV")].close
        self.xly_close = self.datas[symbols.index("XLY")].close
        
        self.datadate = self.datas[0].datetime.date
        self.days_in_trade = 0
        self.max_days_in_trade_mr = 10
        self.max_days_in_trade_mo = 21
        self.num_mr = 21
        self.num_mo = 21*6
        self.regime_state = 0
        self.mrr = 0.02
        self.mor = 0.05
        self.snum = 3
        self.cash = 1000
        self.signal_data = self.read_signals()
        # keep this 
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.period)        
        self.symbols = ['XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']
        self.regimes = ['momentum', 'mean reversion']
        
        
    def stock_return(self, n):
        """calculate return in the past n days """        
        r_xlb = (self.xlb_close[0] - self.xlb_close[-n])/self.xlb_close[-n]
        r_xle = (self.xle_close[0] - self.xle_close[-n])/self.xle_close[-n]
        r_xlf = (self.xlf_close[0] - self.xlf_close[-n])/self.xlf_close[-n]
        r_xli = (self.xli_close[0] - self.xli_close[-n])/self.xli_close[-n]
        r_xlk = (self.xlk_close[0] - self.xlk_close[-n])/self.xlk_close[-n]
        r_xlp = (self.xlp_close[0] - self.xlp_close[-n])/self.xlp_close[-n]
        r_xlu = (self.xlu_close[0] - self.xlu_close[-n])/self.xlu_close[-n]
        r_xlv = (self.xlv_close[0] - self.xlv_close[-n])/self.xlv_close[-n]
        r_xly = (self.xly_close[0] - self.xly_close[-n])/self.xly_close[-n]
        r_list = [r_xlb, r_xle, r_xlf, r_xli, r_xlk, r_xlp, r_xlu, r_xlv, r_xly]        
        
        df = pd.DataFrame(r_list, index = self.symbols, columns = ['return'])
        
        return df
    
    
    
    def sort_return(self, n):
        """sort return in the past n days in ascending order 
           return the bottom and top 3 return stocks """
        
        df = self.stock_return(n)
        df = df.sort_values(by=['return'])
                
        stock_list = [df.index[0:3].tolist(),df.index[6:].tolist()]
        
        return stock_list
    
    
    
    def check_position(self):
        flag = False
        names = []
        for symbol in self.symbols:
            s_size = self.getposition(data=self.datas[symbols.index(symbol)]).size
            if  s_size != 0:
                flag = True
                names.append(symbol)
        return flag, names
            
    
    
        
    
    def shares_to_buy(self,cash, price):
        """calculate the approximate number of shares to buy given cash to spend and stock price"""
        shares = int(cash/price)
        return shares
    
    
    

    def next(self):
        # Simply log the closing price of the series from the reference               
        
        dt = self.datadate(0).strftime('%Y-%m-%d')
        
        signal = self.signal_data['state'].loc[dt]
        
        position, names = self.check_position()
        
        self.log('regime = %s' % self.regimes[signal], '      HAS Position at %s' % " ".join(names[:3]), ' and  at  %s' %  " ".join(names[3:]))

        
        
        # Check if we are in the market
        if not position:
            # if we do not have a position
            
            if signal == 1:
                """mean reversion"""
                
                stock_list = self.sort_return(self.num_mr)
                # print('stocklist = ', stock_list)
                
                self.log('regime = %s' % self.regimes[signal], 'CREATE BUY  for %s' % " ".join(stock_list[0]), ' SELL for %s' %  " ".join(stock_list[0])) 

                # Buy bottom snum stocks
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[0][i])].close[0]
                    shares = self.shares_to_buy(self.cash,price)
                    self.order = self.buy(data = self.datas[symbols.index(stock_list[0][i])], size = shares)
                    
                # Sell top snum stocks    
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[1][i])].close[0]
                    shares = self.shares_to_buy(self.cash,price)
                    self.order = self.sell(data = self.datas[symbols.index(stock_list[1][i])], size = shares)

                self.days_in_trade = 1
                
                self.regime_state = 1
                    
                    
         
            
            else:
                """momentum"""  
                
                stock_list = self.sort_return(self.num_mo)
                # print('stocklist = ', stock_list)
                
                self.log('regime = %s' % self.regimes[signal], '      CREATE SELL for %s' % " ".join(stock_list[0]), ' BUY  for %s' %  " ".join(stock_list[0]))

                # Sell bottom snum stocks
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[0][i])].close[0]
                    shares = self.shares_to_buy(self.cash,price)
                    self.order = self.sell(data = self.datas[symbols.index(stock_list[0][i])], size = shares)
                    
                # Buy top snum stocks    
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[1][i])].close[0]
                    shares = self.shares_to_buy(self.cash,price)
                    self.order = self.buy(data = self.datas[symbols.index(stock_list[1][i])], size = shares)
                    
                self.days_in_trade = 1
                
                self.regime_state = 0
                    
            
                
            

        else:
            # if we have a position
            
            self.days_in_trade += 1
            
            """mean reversion"""
            if (self.regime_state == 1):
            
                # close the position if regime shift or after holding it for max_mr days.
                if signal == 0 or self.days_in_trade == self.max_days_in_trade_mr:
                    num = len(names)
                    for i in range(num):
                        self.close(data=self.datas[symbols.index(names[i])])
                    
                    self.log('regime = %s' % self.regimes[signal], 'CLOSE Position  %s' % " ".join(names[:3]), ' and for  %s' %  " ".join(names[3:]))
                    self.days_in_trade = 0                    
                    self.regime_state = 0 
                    
            
            """momentum"""
            if (self.regime_state == 0):
                
                # close the position if regime shift or after holding it for max_mo days.
                if signal == 1 or self.days_in_trade == self.max_days_in_trade_mo:
                    num = len(names)
                    for i in range(num):
                        self.close(data=self.datas[symbols.index(names[i])])
                    
                    self.log('regime = %s' % self.regimes[signal], '      CLOSE Position  %s' % " ".join(names[:3]), ' and for  %s' %  " ".join(names[3:]))
                    self.days_in_trade = 0                        
                    self.regime_state = 1

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()   

    symbols = ['XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']
    for symbol in symbols:
        datapath = os.path.join('../../../datas/%s.csv' % symbol)

        # Create a Data Feed
        data = bt.feeds.YahooFinanceCSVData(
            dataname=datapath,
            # Do not pass values before this date
            fromdate=datetime(2013, 2, 11),
            # Do not pass values before this date
            todate=datetime(2018, 2, 9),
            # Do not pass values after this date
            reverse=False)

        # Add the Data Feed to Cerebro
        cerebro.adddata(data, name=symbol)


    # Add a strategy
    cerebro.addstrategy(BackTradingStrategy) #, symbols= symbols)
    
    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Write output
    cerebro.addwriter(bt.WriterFile, out='0410-ETFbacktesting-6m.csv',csv=True) 
    
    
    # Analyzer
    cerebro.addanalyzer(btanalyzers.SharpeRatio, _name='mysharpe')
    cerebro.addanalyzer(btanalyzers.TimeDrawDown, _name='DrawDown')
    cerebro.addanalyzer(btanalyzers.TradeAnalyzer, _name='TA')

    
    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    # cerebro.run()
    thestrats = cerebro.run()
    thestrat = thestrats[0]

    # Print out the final result
    print('\nFinal Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    # Print out sharpe ratio and statistics
    print('Sharpe Ratio:', thestrat.analyzers.mysharpe.get_analysis())
    print('Max Draw Down:', thestrat.analyzers.DrawDown.get_analysis(), "\n")
    
    for k,v in thestrat.analyzers.TA.get_analysis().items():
        print(k, ":", v, "\n")
# Out:
# Starting Portfolio Value: 100000.00
# 2014-02-13, regime = momentum,       HAS Position at ,  and  at
# 2014-02-13, regime = momentum,       CREATE SELL for XLP XLE XLU,  BUY  for XLP XLE XLU
# 2014-02-14, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-18, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-19, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-20, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-21, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-24, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-25, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-26, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-27, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-02-28, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-03, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-04, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-05, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-06, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-07, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-10, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-11, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-12, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-13, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-14, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLP XLU XLV
# 2014-03-14, regime = momentum,       CLOSE Position  XLE XLI XLK,  and for  XLP XLU XLV
# 2014-03-17, regime = momentum,       HAS Position at ,  and  at
# 2014-03-17, regime = momentum,       CREATE SELL for XLE XLP XLF,  BUY  for XLE XLP XLF
# 2014-03-18, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-19, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-21, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-24, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-25, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-26, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-27, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-28, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-03-31, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-01, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-02, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-03, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-04, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-07, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-08, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-09, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-10, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-11, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-14, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLV
# 2014-04-14, regime = momentum,       CLOSE Position  XLB XLE XLF,  and for  XLI XLP XLV
# 2014-04-15, regime = momentum,       HAS Position at ,  and  at
# 2014-04-15, regime = momentum,       CREATE SELL for XLY XLF XLP,  BUY  for XLY XLF XLP
# 2014-04-16, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-17, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-21, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-22, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-23, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-24, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-25, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-28, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-29, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-04-30, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-01, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-02, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-05, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-06, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-07, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-08, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-09, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-12, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-13, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-14, regime = momentum,       HAS Position at XLF XLI XLK,  and  at  XLP XLU XLY
# 2014-05-14, regime = momentum,       CLOSE Position  XLF XLI XLK,  and for  XLP XLU XLY
# 2014-05-15, regime = momentum,       HAS Position at ,  and  at
# 2014-05-15, regime = momentum,       CREATE SELL for XLY XLP XLF,  BUY  for XLY XLP XLF
# 2014-05-16, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-19, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-20, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-21, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-22, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-23, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-27, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-28, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-29, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-05-30, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-02, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-03, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-04, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-05, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-06, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-09, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-10, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-11, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-12, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-13, regime = momentum,       HAS Position at XLE XLF XLP,  and  at  XLU XLV XLY
# 2014-06-13, regime = momentum,       CLOSE Position  XLE XLF XLP,  and for  XLU XLV XLY
# 2014-06-16, regime = momentum,       HAS Position at ,  and  at
# 2014-06-16, regime = momentum,       CREATE SELL for XLY XLP XLF,  BUY  for XLY XLP XLF
# 2014-06-17, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-18, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-19, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-23, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-24, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-25, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-26, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-27, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-06-30, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-01, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-02, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-03, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-07, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-08, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-09, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-10, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-11, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-14, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-15, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLY
# 2014-07-15, regime = momentum,       CLOSE Position  XLB XLE XLF,  and for  XLP XLU XLY
# 2014-07-16, regime = momentum,       HAS Position at ,  and  at
# 2014-07-16, regime = momentum,       CREATE SELL for XLY XLF XLI,  BUY  for XLY XLF XLI
# 2014-07-17, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-18, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-21, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-22, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-23, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-24, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-25, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-28, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-29, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-30, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-07-31, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-01, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-04, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-05, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-06, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-07, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-08, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-11, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-12, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-13, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLU XLY
# 2014-08-13, regime = momentum,       CLOSE Position  XLE XLF XLI,  and for  XLK XLU XLY
# 2014-08-14, regime = momentum,       HAS Position at ,  and  at
# 2014-08-14, regime = momentum,       CREATE SELL for XLY XLI XLF,  BUY  for XLY XLI XLF
# 2014-08-15, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-18, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-19, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-21, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-22, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-25, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-26, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-27, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-28, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-08-29, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-02, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-03, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-04, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-05, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-08, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-09, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-10, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-11, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-12, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLY
# 2014-09-12, regime = momentum,       CLOSE Position  XLB XLE XLF,  and for  XLI XLK XLY
# 2014-09-15, regime = momentum,       HAS Position at ,  and  at
# 2014-09-15, regime = momentum,       CREATE SELL for XLY XLU XLI,  BUY  for XLY XLU XLI
# 2014-09-16, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-17, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-18, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-19, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-22, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-23, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-24, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-25, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-26, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-29, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-09-30, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-01, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-02, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-03, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-06, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-07, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-08, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-09, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-10, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-13, regime = momentum,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2014-10-13, regime = momentum,       CLOSE Position  XLE XLI XLK,  and for  XLU XLV XLY
# 2014-10-14, regime = momentum,       HAS Position at ,  and  at
# 2014-10-14, regime = momentum,       CREATE SELL for XLE XLB XLI,  BUY  for XLE XLB XLI
# 2014-10-15, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-16, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-17, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-20, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-21, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-22, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-23, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-24, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-27, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-28, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-29, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-30, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-10-31, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-03, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-04, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-05, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-06, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-07, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-10, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-11, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-11-11, regime = momentum,       CLOSE Position  XLB XLE XLI,  and for  XLK XLP XLV
# 2014-11-12, regime = momentum,       HAS Position at ,  and  at
# 2014-11-12, regime = momentum,       CREATE SELL for XLE XLB XLI,  BUY  for XLE XLB XLI
# 2014-11-13, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-14, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-17, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-18, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-19, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-21, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-24, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-25, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-26, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-28, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLI XLK XLV
# 2014-11-28, regime = mean reversion,       CLOSE Position  XLB XLE XLF,  and for  XLI XLK XLV
# 2014-12-01, regime = momentum,       HAS Position at ,  and  at
# 2014-12-01, regime = momentum,       CREATE SELL for XLE XLB XLI,  BUY  for XLE XLB XLI
# 2014-12-02, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-03, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-04, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-05, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-08, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-09, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-10, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-11, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-12, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-15, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-16, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-17, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-18, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-19, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-22, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-23, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-24, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-26, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-29, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-30, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-30, regime = momentum,       CLOSE Position  XLB XLE XLI,  and for  XLK XLP XLV
# 2014-12-31, regime = momentum,       HAS Position at ,  and  at
# 2014-12-31, regime = momentum,       CREATE SELL for XLE XLB XLI,  BUY  for XLE XLB XLI
# 2015-01-02, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-05, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-06, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-07, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-08, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-09, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-12, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-13, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-14, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-15, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-16, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-20, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-21, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-22, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-23, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-26, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-27, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-28, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-29, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-30, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-01-30, regime = momentum,       CLOSE Position  XLB XLE XLI,  and for  XLP XLU XLV
# 2015-02-02, regime = momentum,       HAS Position at ,  and  at
# 2015-02-02, regime = momentum,       CREATE SELL for XLE XLB XLK,  BUY  for XLE XLB XLK
# 2015-02-03, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-04, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-05, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-06, regime = mean reversion,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-06, regime = mean reversion,       CLOSE Position  XLB XLE XLK,  and for  XLP XLU XLV
# 2015-02-09, regime = momentum,       HAS Position at ,  and  at
# 2015-02-09, regime = momentum,       CREATE SELL for XLE XLB XLK,  BUY  for XLE XLB XLK
# 2015-02-10, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-11, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-12, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-13, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-17, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-18, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-19, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-20, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-23, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-24, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-25, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-26, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-02-27, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-02, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-03, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-04, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-05, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-06, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-09, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-10, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-03-10, regime = momentum,       CLOSE Position  XLB XLE XLK,  and for  XLP XLU XLV
# 2015-03-11, regime = momentum,       HAS Position at ,  and  at
# 2015-03-11, regime = momentum,       CREATE SELL for XLE XLB XLU,  BUY  for XLE XLB XLU
# 2015-03-12, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-13, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-16, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-17, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-18, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-19, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-20, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-23, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-24, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-25, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-26, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-27, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-30, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-03-31, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-04-01, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-04-02, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-04-06, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-04-07, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-04-08, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-04-09, regime = momentum,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-04-09, regime = momentum,       CLOSE Position  XLB XLE XLP,  and for  XLU XLV XLY
# 2015-04-10, regime = momentum,       HAS Position at ,  and  at
# 2015-04-10, regime = momentum,       CREATE SELL for XLE XLB XLU,  BUY  for XLE XLB XLU
# 2015-04-13, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-14, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-15, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-16, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-17, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-20, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-21, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-22, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-23, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-24, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-27, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-28, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-29, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-04-30, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-01, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-04, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-05, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-06, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-07, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-08, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-08, regime = momentum,       CLOSE Position  XLB XLE XLI,  and for  XLU XLV XLY
# 2015-05-11, regime = momentum,       HAS Position at ,  and  at
# 2015-05-11, regime = momentum,       CREATE SELL for XLE XLU XLI,  BUY  for XLE XLU XLI
# 2015-05-12, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-13, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-14, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-15, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-18, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-19, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-20, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-21, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-22, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-26, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-27, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-28, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-05-29, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-01, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-02, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-03, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-04, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-05, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-08, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-09, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-06-09, regime = momentum,       CLOSE Position  XLB XLE XLI,  and for  XLU XLV XLY
# 2015-06-10, regime = momentum,       HAS Position at ,  and  at
# 2015-06-10, regime = momentum,       CREATE SELL for XLU XLI XLP,  BUY  for XLU XLI XLP
# 2015-06-11, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-12, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-15, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-16, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-17, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-18, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-19, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-22, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-23, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-24, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-25, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-26, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-29, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-06-30, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-07-01, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-07-02, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-07-06, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-07-07, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-07-08, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-07-09, regime = momentum,       HAS Position at XLI XLK XLP,  and  at  XLU XLV XLY
# 2015-07-09, regime = momentum,       CLOSE Position  XLI XLK XLP,  and for  XLU XLV XLY
# 2015-07-10, regime = momentum,       HAS Position at ,  and  at
# 2015-07-10, regime = momentum,       CREATE SELL for XLU XLE XLI,  BUY  for XLU XLE XLI
# 2015-07-13, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-14, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-15, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-16, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-17, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-20, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-21, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-22, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-23, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-24, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-27, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-28, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-29, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-30, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-07-31, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-08-03, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-08-04, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-08-05, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-08-06, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-08-07, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLU XLV XLY
# 2015-08-07, regime = momentum,       CLOSE Position  XLE XLF XLI,  and for  XLU XLV XLY
# 2015-08-10, regime = momentum,       HAS Position at ,  and  at
# 2015-08-10, regime = momentum,       CREATE SELL for XLE XLB XLU,  BUY  for XLE XLB XLU
# 2015-08-11, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-12, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-13, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-14, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-17, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-18, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-19, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-21, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2015-08-21, regime = mean reversion,       CLOSE Position  XLB XLE XLF,  and for  XLU XLV XLY
# 2015-08-24, regime = mean reversion,       HAS Position at ,  and  at
# 2015-08-24, regime = mean reversion, CREATE BUY  for XLE XLK XLF,  SELL for XLE XLK XLF
# 2015-08-25, regime = mean reversion,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2015-08-26, regime = mean reversion,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2015-08-27, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2015-08-27, regime = momentum, CLOSE Position  XLE XLF XLI,  and for  XLK XLP XLU
# 2015-08-28, regime = momentum,       HAS Position at ,  and  at
# 2015-08-28, regime = momentum,       CREATE SELL for XLB XLE XLI,  BUY  for XLB XLE XLI
# 2015-08-31, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-01, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-02, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-03, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-04, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-08, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-09, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-10, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-11, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-14, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-15, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-16, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-17, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-18, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-21, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-22, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-23, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-24, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-25, regime = mean reversion,       HAS Position at XLB XLE XLI,  and  at  XLU XLV XLY
# 2015-09-25, regime = mean reversion,       CLOSE Position  XLB XLE XLI,  and for  XLU XLV XLY
# 2015-09-28, regime = mean reversion,       HAS Position at ,  and  at
# 2015-09-28, regime = mean reversion, CREATE BUY  for XLV XLB XLE,  SELL for XLV XLB XLE
# 2015-09-29, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-09-29, regime = momentum, CLOSE Position  XLB XLE XLK,  and for  XLP XLU XLV
# 2015-09-30, regime = momentum,       HAS Position at ,  and  at
# 2015-09-30, regime = momentum,       CREATE SELL for XLE XLB XLI,  BUY  for XLE XLB XLI
# 2015-10-01, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-02, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-05, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-06, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-07, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-08, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-09, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-12, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-13, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-14, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-15, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-16, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-19, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-20, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-21, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-22, regime = mean reversion,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-22, regime = mean reversion,       CLOSE Position  XLB XLE XLI,  and for  XLP XLU XLY
# 2015-10-23, regime = mean reversion,       HAS Position at ,  and  at
# 2015-10-23, regime = mean reversion, CREATE BUY  for XLV XLU XLY,  SELL for XLV XLU XLY
# 2015-10-26, regime = mean reversion,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-27, regime = mean reversion,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-28, regime = mean reversion,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-29, regime = momentum,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-29, regime = momentum, CLOSE Position  XLB XLI XLK,  and for  XLU XLV XLY
# 2015-10-30, regime = momentum,       HAS Position at ,  and  at
# 2015-10-30, regime = momentum,       CREATE SELL for XLE XLB XLI,  BUY  for XLE XLB XLI
# 2015-11-02, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-03, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-04, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-05, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-06, regime = mean reversion,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-06, regime = mean reversion,       CLOSE Position  XLB XLE XLI,  and for  XLK XLP XLY
# 2015-11-09, regime = momentum,       HAS Position at ,  and  at
# 2015-11-09, regime = momentum,       CREATE SELL for XLE XLB XLI,  BUY  for XLE XLB XLI
# 2015-11-10, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-11, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-12, regime = momentum,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-13, regime = mean reversion,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-13, regime = mean reversion,       CLOSE Position  XLB XLE XLI,  and for  XLK XLP XLY
# 2015-11-16, regime = momentum,       HAS Position at ,  and  at
# 2015-11-16, regime = momentum,       CREATE SELL for XLE XLB XLV,  BUY  for XLE XLB XLV
# 2015-11-17, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-18, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-19, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-20, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-23, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-24, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-25, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-27, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-11-30, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-01, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-02, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-03, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-04, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-07, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-08, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-09, regime = mean reversion,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-09, regime = mean reversion,       CLOSE Position  XLB XLE XLK,  and for  XLP XLV XLY
# 2015-12-10, regime = momentum,       HAS Position at ,  and  at
# 2015-12-10, regime = momentum,       CREATE SELL for XLE XLB XLV,  BUY  for XLE XLB XLV
# 2015-12-11, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-14, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-15, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-16, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-17, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-18, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-21, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-22, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-23, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-24, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-28, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-29, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-30, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2015-12-31, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2016-01-04, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2016-01-05, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2016-01-06, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2016-01-07, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2016-01-08, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2016-01-11, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2016-01-11, regime = momentum,       CLOSE Position  XLB XLE XLK,  and for  XLP XLV XLY
# 2016-01-12, regime = momentum,       HAS Position at ,  and  at
# 2016-01-12, regime = momentum,       CREATE SELL for XLE XLB XLV,  BUY  for XLE XLB XLV
# 2016-01-13, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2016-01-14, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2016-01-15, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2016-01-19, regime = mean reversion,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2016-01-19, regime = mean reversion,       CLOSE Position  XLB XLE XLK,  and for  XLP XLU XLV
# 2016-01-20, regime = mean reversion,       HAS Position at ,  and  at
# 2016-01-20, regime = mean reversion, CREATE BUY  for XLE XLB XLF,  SELL for XLE XLB XLF
# 2016-01-21, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-01-22, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# ...
# 2017-07-31, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-01, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-02, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-03, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-04, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-07, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-08, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-09, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-10, regime = momentum,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-08-10, regime = momentum,       CLOSE Position  XLE XLF XLI,  and for  XLK XLP XLV
# 2017-08-11, regime = momentum,       HAS Position at ,  and  at
# 2017-08-11, regime = momentum,       CREATE SELL for XLE XLB XLP,  BUY  for XLE XLB XLP
# 2017-08-14, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-15, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-16, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-17, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-18, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-21, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-22, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-23, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-24, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-25, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-28, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-29, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-30, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-08-31, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-09-01, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-09-05, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-09-06, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-09-07, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-09-08, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-09-11, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2017-09-11, regime = momentum,       CLOSE Position  XLB XLE XLK,  and for  XLP XLU XLV
# 2017-09-12, regime = momentum,       HAS Position at ,  and  at
# 2017-09-12, regime = momentum,       CREATE SELL for XLE XLF XLP,  BUY  for XLE XLF XLP
# 2017-09-13, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-14, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-15, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-18, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-19, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-21, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-22, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-25, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-26, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-27, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-28, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-09-29, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-02, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-03, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-04, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-05, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-06, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-09, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-10, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLV
# 2017-10-10, regime = momentum,       CLOSE Position  XLB XLE XLF,  and for  XLK XLP XLV
# 2017-10-11, regime = momentum,       HAS Position at ,  and  at
# 2017-10-11, regime = momentum,       CREATE SELL for XLE XLP XLY,  BUY  for XLE XLP XLY
# 2017-10-12, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-13, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-16, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-17, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-18, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-19, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-23, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-24, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-25, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-26, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-27, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-10-27, regime = mean reversion,       CLOSE Position  XLB XLE XLF,  and for  XLK XLP XLY
# 2017-10-30, regime = momentum,       HAS Position at ,  and  at
# 2017-10-30, regime = momentum,       CREATE SELL for XLP XLY XLE,  BUY  for XLP XLY XLE
# 2017-10-31, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-01, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-02, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-03, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-06, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-07, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-08, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-09, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-10, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-13, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-14, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-15, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-16, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-17, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-20, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-21, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-22, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-24, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-27, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-28, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-28, regime = momentum,       CLOSE Position  XLB XLE XLF,  and for  XLK XLP XLY
# 2017-11-29, regime = momentum,       HAS Position at ,  and  at
# 2017-11-29, regime = momentum,       CREATE SELL for XLP XLY XLE,  BUY  for XLP XLY XLE
# 2017-11-30, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-12-01, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-12-04, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-12-04, regime = mean reversion,       CLOSE Position  XLB XLE XLF,  and for  XLK XLP XLY
# 2017-12-05, regime = momentum,       HAS Position at ,  and  at
# 2017-12-05, regime = momentum,       CREATE SELL for XLP XLU XLY,  BUY  for XLP XLU XLY
# 2017-12-06, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-07, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-08, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-11, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-12, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-13, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-14, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-15, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-18, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-19, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-20, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-21, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-22, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-26, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-27, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-28, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2017-12-29, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2018-01-02, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2018-01-03, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2018-01-04, regime = momentum,       HAS Position at XLB XLF XLI,  and  at  XLP XLU XLY
# 2018-01-04, regime = momentum,       CLOSE Position  XLB XLF XLI,  and for  XLP XLU XLY
# 2018-01-05, regime = momentum,       HAS Position at ,  and  at
# 2018-01-05, regime = momentum,       CREATE SELL for XLU XLP XLV,  BUY  for XLU XLP XLV
# 2018-01-08, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-09, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-10, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-11, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-12, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-16, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-17, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-18, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-19, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-22, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-23, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-24, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-25, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-26, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-29, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-30, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-01-31, regime = momentum,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-02-01, regime = mean reversion,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2018-02-01, regime = mean reversion,       CLOSE Position  XLB XLE XLK,  and for  XLP XLU XLV
# 2018-02-02, regime = mean reversion,       HAS Position at ,  and  at
# 2018-02-02, regime = mean reversion, CREATE BUY  for XLU XLE XLB,  SELL for XLU XLE XLB
# 2018-02-05, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2018-02-06, regime = mean reversion,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2018-02-07, regime = momentum,       HAS Position at XLB XLE XLF,  and  at  XLU XLV XLY
# 2018-02-07, regime = momentum, CLOSE Position  XLB XLE XLF,  and for  XLU XLV XLY
# 2018-02-08, regime = momentum,       HAS Position at ,  and  at
# 2018-02-08, regime = momentum,       CREATE SELL for XLU XLP XLV,  BUY  for XLU XLP XLV
#
# Final Portfolio Value: 100142.36
# Sharpe Ratio: OrderedDict([('sharperatio', -5.930190376418824)])
# Max Draw Down: OrderedDict([('maxdrawdown', 1.04831217434588), ('maxdrawdownperiod', 477)])
#
# total : AutoOrderedDict([('total', 414), ('open', 0), ('closed', 414)])
#
# streak : AutoOrderedDict([('won', AutoOrderedDict([('current', 2), ('longest', 9)])), ('lost', AutoOrderedDict([('current', 0), ('longest', 8)]))])
#
# pnl : AutoOrderedDict([('gross', AutoOrderedDict([('total', 142.36000000000075), ('average', 0.34386473429951875)])), ('net', AutoOrderedDict([('total', 142.36000000000075), ('average', 0.34386473429951875)]))])
#
# won : AutoOrderedDict([('total', 219), ('pnl', AutoOrderedDict([('total', 5454.720000000001), ('average', 24.907397260273978), ('max', 125.29000000000019)]))])
#
# lost : AutoOrderedDict([('total', 195), ('pnl', AutoOrderedDict([('total', -5312.359999999999), ('average', -27.24287179487179), ('max', -158.59999999999985)]))])
#
# long : AutoOrderedDict([('total', 207), ('pnl', AutoOrderedDict([('total', 740.5400000000012), ('average', 3.57748792270532), ('won', AutoOrderedDict([('total', 2975.8500000000004), ('average', 22.89115384615385), ('max', 125.29000000000019)])), ('lost', AutoOrderedDict([('total', -2235.3100000000004), ('average', -29.030000000000005), ('max', -158.59999999999985)]))])), ('won', 130), ('lost', 77)])
#
# short : AutoOrderedDict([('total', 207), ('pnl', AutoOrderedDict([('total', -598.1800000000007), ('average', -2.8897584541062837), ('won', AutoOrderedDict([('total', 2478.869999999999), ('average', 27.85247191011235), ('max', 120.00000000000011)])), ('lost', AutoOrderedDict([('total', -3077.050000000001), ('average', -26.076694915254247), ('max', -139.2299999999999)]))])), ('won', 89), ('lost', 118)])
#
# len : AutoOrderedDict([('total', 5616), ('average', 13.565217391304348), ('max', 20), ('min', 1), ('won', AutoOrderedDict([('total', 2884), ('average', 13.168949771689498), ('max', 20), ('min', 1)])), ('lost', AutoOrderedDict([('total', 2732), ('average', 14.01025641025641), ('max', 20), ('min', 1)])), ('long', AutoOrderedDict([('total', 2808), ('average', 13.565217391304348), ('max', 20), ('min', 1), ('won', AutoOrderedDict([('total', 1761), ('average', 13.546153846153846), ('max', 20), ('min', 1)])), ('lost', AutoOrderedDict([('total', 1047), ('average', 13.597402597402597), ('max', 20), ('min', 1)]))])), ('short', AutoOrderedDict([('total', 2808), ('average', 13.565217391304348), ('max', 20), ('min', 1), ('won', AutoOrderedDict([('total', 1123), ('average', 12.617977528089888), ('max', 20), ('min', 1)])), ('lost', AutoOrderedDict([('total', 1685), ('average', 14.279661016949152), ('max', 20), ('min', 1)]))]))])

# %%
# calculate pnl using excel data
import pandas as pd
import matplotlib.pyplot as plt

dtime = pd.read_csv('datetime.csv')
data = pd.read_csv('0410-ETFbacktesting-6m.csv').fillna(value = 0)
data = data[:1260]

df = data[data.columns[-9:]].copy()
df.columns = symbols
df['datetime'] = dtime[['datetime']].copy()

n = len(df)
df['cumulative_pnl'] = df['XLB']

cpnl = 0.
count_plus = 0
count_minus = 0

for t in range(n):
    pnl = 0.
    for i in range(len(symbols)):
        profit = df[symbols[i]].iloc[t]
        # print('profit = ', profit)
        pnl = pnl + profit
        if (profit > 0.):
            count_plus +=1
        elif (profit < 0.):
            count_minus +=1
         
    cpnl = cpnl + pnl
    # print('cpnl = ', cpnl)
    df['cumulative_pnl'].iloc[t] = cpnl
# Out:
# /home/project/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
plus_percent = 1.0*count_plus/(count_plus*1.0+count_minus*1.0) 
print('percentage of trading that make positive profits = ', plus_percent)
# Out:
# percentage of trading that make positive profits =  0.5289855072463768

# %%
# convert string to datetime
df["datetime"] = df["datetime"].apply(lambda x: datetime.strptime(x,"%m/%d/%Y"))

# plot PNL figures 
plt.figure(figsize=(16, 4))
plt.plot(df['datetime'], df['cumulative_pnl'] ,'.') 
plt.xlabel("Time")
plt.ylabel("cumulative pnl")
plt.title("Daily PNL")
plt.show()

# %%
df.to_csv(r'hmm_regime_wealth_6m.csv',header=list(df),index=list(df.index),sep=",",mode="a")

# %%
data = pd.read_csv('0410-ETFbacktesting-hmm-pnl.csv')
df = data[:1260]
# convert string to datetime
df["datetime"] = df["datetime"].apply(lambda x: datetime.strptime(x,"%m/%d/%Y"))

# plot figures for pnl of all versions
plt.figure(figsize=(16, 4))
plt.plot(df['datetime'], df['pnl_scored_v1'], label = 'pnl_scored_v1 SR = 0.0626')
plt.plot(df['datetime'], df['pnl_scored_v2'], label = 'pnl_scored_v2 SR = 0.0603')
plt.plot(df['datetime'], df['pnl_6m'], label = 'pnl_06m SR = 0.0719')
plt.plot(df['datetime'], df['pnl_8m'], label = 'pnl_08m SR = 0.0348')
plt.plot(df['datetime'], df['pnl_10m'], label = 'pnl_10m SR = 0.3320')
plt.plot(df['datetime'], df['pnl_12m'], label = 'pnl_12m SR = 0.4397')
plt.legend(loc='best')
plt.show()
