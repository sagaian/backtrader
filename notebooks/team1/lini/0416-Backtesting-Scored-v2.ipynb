# %% [markdown]
# # Backtesting the HMM Model

# %% [markdown]
# Signals are identifed by the hmm model and imported into the system.
#
#     When signal = 1, we enter the mean reversion position.
#     When signal = 0, we enter the momentum position.
#
#
# Mean Reversion Strategy:
#
#      1.We rank the returns of ETF stocks in the past month
#      2.For bottom 3 stocks, we buy
#      3.For top 3 stocks, we sell
#      4.We close the position every 10 days
#
#
# Momentum Strategy (using scores):
#
#      1.We rank the returns of ETF stocks in the past n_i months
#      2.Given different n_i, we obtain the ranking score of each stocks
#      3.For bottom 3 stocks, we sell
#      4.For top 3 stocks, we buy
#      5.We close the position every month

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt

import pandas as pd
from datetime import datetime
import backtrader.analyzers as btanalyzers

# %%
class RSI_Oversold(bt.Indicator):
    lines = ('oversold',)
    
    params = (
        ('level', 30),    
    )

    def __init__(self):
        self.lines.oversold = bt.indicators.RSI(self.data) < self.p.level

        
class DummyInd(bt.Indicator):
    lines = ('dummyline',)

    params = (('value', 5),)

    def __init__(self):
        self.lines.dummyline = bt.Max(0.0, self.params.value)

        
# Create a Stratey
class BackTradingStrategy(bt.Strategy):
    params = (
        ('period', 255),
        ("max_days_in_trade", 10)
    )

    def log(self, txt, txt2, txt3, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s, %s, %s' % (dt.isoformat(), txt, txt2, txt3))
    
    
    def log2(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))
        
        
    def read_signals(self):
        signal_data = pd.read_csv("hmm_regime_signals.csv")
        signal_data["datetime"] = signal_data["datetime"].apply(lambda x: datetime.strptime(x,"%m/%d/%Y"))
        signal_data = signal_data.set_index('datetime')
        
        return signal_data
        

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        # How to access individual etf
        self.xlb_close = self.datas[symbols.index("XLB")].close
        self.xle_close = self.datas[symbols.index("XLE")].close
        self.xlf_close = self.datas[symbols.index("XLF")].close
        self.xli_close = self.datas[symbols.index("XLI")].close
        self.xlk_close = self.datas[symbols.index("XLK")].close
        self.xlp_close = self.datas[symbols.index("XLP")].close
        self.xlu_close = self.datas[symbols.index("XLU")].close
        self.xlv_close = self.datas[symbols.index("XLV")].close
        self.xly_close = self.datas[symbols.index("XLY")].close
        
        self.datadate = self.datas[0].datetime.date
        self.days_in_trade = 0
        self.max_days_in_trade_mr = 10
        self.max_days_in_trade_mo = 21
        self.num_mr = 21
        self.num_mo = 21*6
        self.num_mrs = [10, 15, 20, 25]
        self.num_mos = [21*6, 21*8, 21*10, 21*12]
        self.regime_state = 0
        self.mrr = 0.02
        self.mor = 0.05
        self.snum = 3 
        self.cash = 1000
        self.signal_data = self.read_signals()
        # keep this 
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.period)        
        self.symbols = ['XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']
        self.regimes = ['momentum', 'mean reversion']
        self.invest = 0
        self.path = []
        
        
    def stock_return(self, n):
        """calculate return in the past n days """        
        r_xlb = (self.xlb_close[0] - self.xlb_close[-n])/self.xlb_close[-n]
        r_xle = (self.xle_close[0] - self.xle_close[-n])/self.xle_close[-n]
        r_xlf = (self.xlf_close[0] - self.xlf_close[-n])/self.xlf_close[-n]
        r_xli = (self.xli_close[0] - self.xli_close[-n])/self.xli_close[-n]
        r_xlk = (self.xlk_close[0] - self.xlk_close[-n])/self.xlk_close[-n]
        r_xlp = (self.xlp_close[0] - self.xlp_close[-n])/self.xlp_close[-n]
        r_xlu = (self.xlu_close[0] - self.xlu_close[-n])/self.xlu_close[-n]
        r_xlv = (self.xlv_close[0] - self.xlv_close[-n])/self.xlv_close[-n]
        r_xly = (self.xly_close[0] - self.xly_close[-n])/self.xly_close[-n]
        r_list = [r_xlb, r_xle, r_xlf, r_xli, r_xlk, r_xlp, r_xlu, r_xlv, r_xly]        
        
        df = pd.DataFrame(r_list, index = self.symbols, columns = ['return'])
        
        return df
    
    
    
    def sort_return(self, n):
        """sort return in the past n days in ascending order 
           return the bottom and top 3 return stocks """
        
        df = self.stock_return(n)
        df = df.sort_values(by=['return'])                
        stock_list = [df.index[0:3].tolist(),df.index[6:].tolist()]
        
        return stock_list
    
    
    def sort_return2(self, nums):
        """sort return in the past n_i days in ascending order 
           For each stock, its rank @ n_i is the score_i
           For each stock, its cumulative score = sum of score_i for all i
           return the bottom and top 3 scored stocks """
        
        n = len(nums)
        snum = len(symbols)
        scores=[0]*snum
        for i in range(n):
            s = []
            df = self.stock_return(nums[i])
            df = df.sort_values(by=['return'])
            sorted_index = df.index.tolist()
            dictionary = self.list_to_dict(sorted_index)
            for symbol in symbols:
                s.append(dictionary[symbol])
            for j in range(snum):
                scores[j] = scores[j] + s[j]
        ddf = pd.DataFrame(scores, index = symbols, columns=['return'])
        ddf = ddf.sort_values(by=['return'])
        stock_list = [ddf.index[0:3].tolist(),ddf.index[snum-3:].tolist()]
        
        return stock_list
        
        
    
    def list_to_dict(self,llist):  
        dct = {} 
        n = len(llist)
        for i in range(n):
            item = llist[i]
            dct[item] = i  
        return dct 

    
    def check_position(self):
        flag = False
        names = []
        for symbol in self.symbols:
            s_size = self.getposition(data=self.datas[symbols.index(symbol)]).size
            if  s_size != 0:
                flag = True
                names.append(symbol)
        return flag, names
    
    
    def shares_to_buy(self,cash, price):
        """calculate the approximate number of shares to buy given cash to spend and stock price"""
        shares = int(cash/price)
        return shares
            
                
    

    def next(self):
        # Simply log the closing price of the series from the reference               
        #print('investment = ', self.invest)
        dt = self.datadate(0).strftime('%Y-%m-%d')
        
        signal = self.signal_data['state'].loc[dt]
        
        position, names = self.check_position()
        
        #self.log('regime = %s' % self.regimes[signal], '      HAS Position at %s' % " ".join(names[:3]), ' and  at  %s' %  " ".join(names[3:]))
        self.log(' %5.4f' % self.invest, '      HAS Position at %s' % " ".join(names[:3]), ' and  at  %s' %  " ".join(names[3:]))

        
        
        # Check if we are in the market
        if not position:
            # if we do not have a position
            
            if signal == 1:
                """mean reversion"""
                
                stock_list = self.sort_return2(self.num_mrs)
                # print('stocklist = ', stock_list)
                
                # self.log('regime = %s' % self.regimes[signal], 'CREATE BUY  for %s' % " ".join(stock_list[0]), ' SELL for %s' %  " ".join(stock_list[0])) 

                # Buy bottom snum stocks
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[0][i])].close[0]
                    shares = self.shares_to_buy(self.cash,price) 
                    long_value = price * shares
                    self.order = self.buy(data = self.datas[symbols.index(stock_list[0][i])], size = shares)
                    
                # Sell top snum stocks    
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[1][i])].close[0]
                    shares = self.shares_to_buy(self.cash, price)
                    self.order = self.sell(data = self.datas[symbols.index(stock_list[1][i])], size = shares)
                    short_value = price*shares
                self.invest = long_value - short_value
                self.path.append([dt, long_value-short_value])

                self.days_in_trade = 1
                
                self.regime_state = 1
                    
                    
         
            
            else:
                """momentum"""  
                
                stock_list = self.sort_return2(self.num_mos)
                #print('stocklist = ', stock_list)
                
                #self.log('regime = %s' % self.regimes[signal], '      CREATE SELL for %s' % " ".join(stock_list[0]), ' BUY  for %s' %  " ".join(stock_list[0]))

                # Sell bottom snum stocks
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[0][i])].close[0]
                    shares = self.shares_to_buy(self.cash,price)
                    short_value = price*shares
                    self.order = self.sell(data = self.datas[symbols.index(stock_list[0][i])], size = shares)
                    
                # Buy top snum stocks    
                for i in range(self.snum):
                    price = self.datas[symbols.index(stock_list[1][i])].close[0]
                    shares = self.shares_to_buy(self.cash,price)
                    long = price*shares
                    long_value = price*shares
                    self.order = self.buy(data = self.datas[symbols.index(stock_list[1][i])], size = shares)
                self.invest = long_value - short_value
                self.path.append([dt, long_value-short_value])
                    
                self.days_in_trade = 1
                
                self.regime_state = 0
                    
            
                
            

        else:
            # if we have a position
            
            self.days_in_trade += 1
            self.path.append([dt, self.invest])
            
            """mean reversion"""
            if (self.regime_state == 1):
            
                # close the position if regime shift or after holding it for max_mr days.
                if signal == 0 or self.days_in_trade == self.max_days_in_trade_mr:
                    num = len(names)
                    for i in range(num):
                        self.close(data=self.datas[symbols.index(names[i])])
                    
                    #self.log('regime = %s' % self.regimes[signal], 'CLOSE Position  %s' % " ".join(names[:3]), ' and for  %s' %  " ".join(names[3:]))
                    self.days_in_trade = 0                    
                    self.regime_state = 0 
                    
            
            """momentum"""
            if (self.regime_state == 0):
                
                # close the position if regime shift or after holding it for max_mo days.
                if signal == 1 or self.days_in_trade == self.max_days_in_trade_mo:
                    num = len(names)
                    for i in range(num):
                        self.close(data=self.datas[symbols.index(names[i])])
                    
                    # self.log('regime = %s' % self.regimes[signal], '      CLOSE Position  %s' % " ".join(names[:3]), ' and for  %s' %  " ".join(names[3:]))
                    self.days_in_trade = 0                        
                    self.regime_state = 1

# %%
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()   

    symbols = ['XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']
    for symbol in symbols:
        datapath = os.path.join('../../../datas/%s.csv' % symbol)

        # Create a Data Feed
        data = bt.feeds.YahooFinanceCSVData(
            dataname=datapath,
            # Do not pass values before this date
            fromdate=datetime(2013, 2, 11),
            # Do not pass values before this date
            todate=datetime(2018, 2, 9),
            # Do not pass values after this date
            reverse=False)

        # Add the Data Feed to Cerebro
        cerebro.adddata(data, name=symbol)


    # Add a strategy
    cerebro.addstrategy(BackTradingStrategy) #, symbols= symbols)
    
    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Write output
    cerebro.addwriter(bt.WriterFile, out='0416-ETFbacktesting-Scored.csv',csv=True)  
    
    
    # Analyzer
    cerebro.addanalyzer(btanalyzers.SharpeRatio, _name='mysharpe')
    cerebro.addanalyzer(btanalyzers.TimeDrawDown, _name='DrawDown')
    cerebro.addanalyzer(btanalyzers.TradeAnalyzer, _name='TA')

    
    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    # cerebro.run()
    thestrats = cerebro.run()
    thestrat = thestrats[0]

    # Print out the final result
    print('\nFinal Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    # Print out sharpe ratio and statistics
    print('Sharpe Ratio:', thestrat.analyzers.mysharpe.get_analysis())
    print('Max Draw Down:', thestrat.analyzers.DrawDown.get_analysis(), "\n")
    
   # for k,v in thestrat.analyzers.TA.get_analysis().items():
   #     print(k, ":", v, "\n")
# Out:
# Starting Portfolio Value: 100000.00
# 2014-02-13,  0.0000,       HAS Position at ,  and  at
# 2014-02-14,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-18,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-19,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-20,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-21,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-24,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-25,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-26,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-27,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-02-28,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-03,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-04,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-05,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-06,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-07,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-10,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-11,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-12,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-13,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-14,  6.8800,       HAS Position at XLE XLI XLP,  and  at  XLU XLV XLY
# 2014-03-17,  6.8800,       HAS Position at ,  and  at
# 2014-03-18,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-19,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-20,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-21,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-24,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-25,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-26,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-27,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-28,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-03-31,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-01,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-02,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-03,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-04,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-07,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-08,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-09,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-10,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-11,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-14,  -23.2900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2014-04-15,  -23.2900,       HAS Position at ,  and  at
# 2014-04-16,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-17,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-21,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-22,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-23,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-24,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-25,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-28,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-29,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-04-30,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-01,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-02,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-05,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-06,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-07,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-08,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-09,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-12,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-13,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-14,  -43.3700,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-15,  -43.3700,       HAS Position at ,  and  at
# 2014-05-16,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-19,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-20,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-21,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-22,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-23,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-27,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-28,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-29,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-05-30,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-02,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-03,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-04,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-05,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-06,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-09,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-10,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-11,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-12,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-13,  -6.6600,       HAS Position at XLB XLF XLI,  and  at  XLP XLV XLY
# 2014-06-16,  -6.6600,       HAS Position at ,  and  at
# 2014-06-17,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-18,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-19,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-20,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-23,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-24,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-25,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-26,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-27,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-06-30,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-01,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-02,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-03,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-07,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-08,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-09,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-10,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-11,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-14,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-15,  -15.9400,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLY
# 2014-07-16,  -15.9400,       HAS Position at ,  and  at
# 2014-07-17,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-18,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-21,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-22,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-23,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-24,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-25,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-28,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-29,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-30,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-07-31,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-01,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-04,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-05,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-06,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-07,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-08,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-11,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-12,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-13,  5.3400,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2014-08-14,  5.3400,       HAS Position at ,  and  at
# 2014-08-15,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-18,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-19,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-20,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-21,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-22,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-25,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-26,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-27,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-28,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-08-29,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-02,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-03,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-04,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-05,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-08,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-09,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-10,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-11,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-12,  1.1700,       HAS Position at XLB XLF XLK,  and  at  XLP XLV XLY
# 2014-09-15,  1.1700,       HAS Position at ,  and  at
# 2014-09-16,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-17,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-18,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-19,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-22,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-23,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-24,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-25,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-26,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-29,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-09-30,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-01,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-02,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-03,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-06,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-07,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-08,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-09,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-10,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-13,  24.2500,       HAS Position at XLB XLI XLK,  and  at  XLP XLV XLY
# 2014-10-14,  24.2500,       HAS Position at ,  and  at
# 2014-10-15,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-16,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-17,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-20,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-21,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-22,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-23,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-24,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-27,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-28,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-29,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-30,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-10-31,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-03,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-04,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-05,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-06,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-07,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-10,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-11,  13.5900,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-12,  13.5900,       HAS Position at ,  and  at
# 2014-11-13,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-14,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-17,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-18,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-19,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-20,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-21,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-24,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-25,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-26,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-11-28,  3.3000,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2014-12-01,  3.3000,       HAS Position at ,  and  at
# 2014-12-02,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-03,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-04,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-05,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-08,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-09,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-10,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-11,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-12,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-15,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-16,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-17,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-18,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-19,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-22,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-23,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-24,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-26,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-29,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-30,  -5.3600,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLV
# 2014-12-31,  -5.3600,       HAS Position at ,  and  at
# 2015-01-02,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-05,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-06,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-07,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-08,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-09,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-12,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-13,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-14,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-15,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-16,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-20,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-21,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-22,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-23,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-26,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-27,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-28,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-29,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-01-30,  22.9200,       HAS Position at XLB XLE XLI,  and  at  XLK XLU XLV
# 2015-02-02,  22.9200,       HAS Position at ,  and  at
# 2015-02-03,  -31.6600,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2015-02-04,  -31.6600,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2015-02-05,  -31.6600,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2015-02-06,  -31.6600,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2015-02-09,  -31.6600,       HAS Position at ,  and  at
# 2015-02-10,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-11,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-12,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-13,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-17,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-18,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-19,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-20,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-23,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-24,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-25,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-26,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-02-27,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-02,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-03,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-04,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-05,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-06,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-09,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-10,  40.9200,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLV
# 2015-03-11,  40.9200,       HAS Position at ,  and  at
# 2015-03-12,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-13,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-16,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-17,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-18,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-19,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-20,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-23,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-24,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-25,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-26,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-27,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-30,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-03-31,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-04-01,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-04-02,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-04-06,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-04-07,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-04-08,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-04-09,  -22.3200,       HAS Position at XLB XLE XLK,  and  at  XLU XLV XLY
# 2015-04-10,  -22.3200,       HAS Position at ,  and  at
# 2015-04-13,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-14,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-15,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-16,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-17,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-20,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-21,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-22,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-23,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-24,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-27,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-28,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-29,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-04-30,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-05-01,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-05-04,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-05-05,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-05-06,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-05-07,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-05-08,  1.6400,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2015-05-11,  1.6400,       HAS Position at ,  and  at
# 2015-05-12,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-13,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-14,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-15,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-18,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-19,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-20,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-21,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-22,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-26,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-27,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-28,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-05-29,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-01,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-02,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-03,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-04,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-05,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-08,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-09,  25.6800,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-10,  25.6800,       HAS Position at ,  and  at
# 2015-06-11,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-12,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-15,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-16,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-17,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-18,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-19,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-22,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-23,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-24,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-25,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-26,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-29,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-06-30,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-07-01,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-07-02,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-07-06,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-07-07,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-07-08,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-07-09,  -18.5500,       HAS Position at XLE XLI XLK,  and  at  XLU XLV XLY
# 2015-07-10,  -18.5500,       HAS Position at ,  and  at
# 2015-07-13,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-14,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-15,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-16,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-17,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-20,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-21,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-22,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-23,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-24,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-27,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-28,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-29,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-30,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-07-31,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-03,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-04,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-05,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-06,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-07,  -25.1600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-10,  -25.1600,       HAS Position at ,  and  at
# 2015-08-11,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-12,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-13,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-14,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-17,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-18,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-19,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-20,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-21,  14.0600,       HAS Position at XLB XLE XLP,  and  at  XLU XLV XLY
# 2015-08-24,  14.0600,       HAS Position at ,  and  at
# 2015-08-25,  3.5100,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2015-08-26,  3.5100,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2015-08-27,  3.5100,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2015-08-28,  3.5100,       HAS Position at ,  and  at
# 2015-08-31,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-01,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-02,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-03,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-04,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-08,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-09,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-10,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-11,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-14,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-15,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-16,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-17,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-18,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-21,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-22,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-23,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-24,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-25,  -14.9600,       HAS Position at XLB XLE XLI,  and  at  XLP XLV XLY
# 2015-09-28,  -14.9600,       HAS Position at ,  and  at
# 2015-09-29,  -32.4100,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2015-09-30,  -32.4100,       HAS Position at ,  and  at
# 2015-10-01,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-02,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-05,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-06,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-07,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-08,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-09,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-12,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-13,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-14,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-15,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-16,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-19,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-20,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-21,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-22,  -66.6900,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2015-10-23,  -66.6900,       HAS Position at ,  and  at
# 2015-10-26,  -46.7500,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-27,  -46.7500,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-28,  -46.7500,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-29,  -46.7500,       HAS Position at XLB XLI XLK,  and  at  XLU XLV XLY
# 2015-10-30,  -46.7500,       HAS Position at ,  and  at
# 2015-11-02,  -44.4900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-03,  -44.4900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-04,  -44.4900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-05,  -44.4900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-06,  -44.4900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-09,  -44.4900,       HAS Position at ,  and  at
# 2015-11-10,  -50.0400,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLY
# 2015-11-11,  -50.0400,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLY
# 2015-11-12,  -50.0400,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLY
# 2015-11-13,  -50.0400,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLY
# 2015-11-16,  -50.0400,       HAS Position at ,  and  at
# 2015-11-17,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-18,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-19,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-20,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-23,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-24,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-25,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-27,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-11-30,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-01,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-02,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-03,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-04,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-07,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-08,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-09,  5.8300,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-10,  5.8300,       HAS Position at ,  and  at
# 2015-12-11,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-14,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-15,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-16,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-17,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-18,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-21,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-22,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-23,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-24,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-28,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-29,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-30,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2015-12-31,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2016-01-04,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2016-01-05,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2016-01-06,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2016-01-07,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2016-01-08,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2016-01-11,  -43.4100,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLY
# 2016-01-12,  -43.4100,       HAS Position at ,  and  at
# 2016-01-13,  30.0600,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2016-01-14,  30.0600,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2016-01-15,  30.0600,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2016-01-19,  30.0600,       HAS Position at XLB XLE XLI,  and  at  XLP XLU XLY
# 2016-01-20,  30.0600,       HAS Position at ,  and  at
# 2016-01-21,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-01-22,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-01-25,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-01-26,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-01-27,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-01-28,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-01-29,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-01,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-02,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-03,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-04,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-05,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-08,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-09,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-10,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-11,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-12,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-16,  31.9100,       HAS Position at XLB XLE XLF,  and  at  XLP XLU XLV
# 2016-02-17,  31.9100,       HAS Position at ,  and  at
# 2016-02-18,  -7.3000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-02-19,  -7.3000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-02-22,  -7.3000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-02-23,  -7.3000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-02-24,  -7.3000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-02-25,  -7.3000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-02-26,  -7.3000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-02-29,  -7.3000,       HAS Position at ,  and  at
# 2016-03-01,  12.8100,       HAS Position at XLB XLE XLF,  and  at  XLI XLV XLY
# 2016-03-02,  12.8100,       HAS Position at XLB XLE XLF,  and  at  XLI XLV XLY
# 2016-03-03,  12.8100,       HAS Position at ,  and  at
# 2016-03-04,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-07,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-08,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-09,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-10,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-11,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-14,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-15,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-16,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-17,  -30.1800,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2016-03-18,  -30.1800,       HAS Position at ,  and  at
# 2016-03-21,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-03-22,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-03-23,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-03-24,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-03-28,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-03-29,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-03-30,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-03-31,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-01,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-04,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-05,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-06,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-07,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-08,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-11,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-12,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-13,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-14,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-15,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-18,  -27.8700,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-19,  -27.8700,       HAS Position at ,  and  at
# 2016-04-20,  50.0900,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2016-04-21,  50.0900,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2016-04-22,  50.0900,       HAS Position at XLB XLE XLK,  and  at  XLP XLU XLV
# 2016-04-25,  50.0900,       HAS Position at ,  and  at
# 2016-04-26,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-27,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-28,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-04-29,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-02,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-03,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-04,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-05,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-06,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-09,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-10,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-11,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-12,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-13,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-16,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-17,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-18,  24.1000,       HAS Position at XLE XLF XLK,  and  at  XLP XLU XLV
# 2016-05-19,  24.1000,       HAS Position at ,  and  at
# 2016-05-20,  2.4200,       HAS Position at XLE XLF XLI,  and  at  XLP XLV XLY
# 2016-05-23,  2.4200,       HAS Position at ,  and  at
# 2016-05-24,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-05-25,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-05-26,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-05-27,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-05-31,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-01,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-02,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-03,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-06,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-07,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-08,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-09,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-10,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-13,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-14,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-15,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-16,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-17,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-20,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-21,  51.6100,       HAS Position at XLE XLF XLI,  and  at  XLP XLU XLV
# 2016-06-22,  51.6100,       HAS Position at ,  and  at
# 2016-06-23,  -41.3400,       HAS Position at XLB XLF XLP,  and  at  XLU XLV XLY
# 2016-06-24,  -41.3400,       HAS Position at XLB XLF XLP,  and  at  XLU XLV XLY
# 2016-06-27,  -41.3400,       HAS Position at ,  and  at
# 2016-06-28,  8.1100,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLU
# 2016-06-29,  8.1100,       HAS Position at XLB XLE XLF,  and  at  XLI XLP XLU
# 2016-06-30,  8.1100,       HAS Position at ,  and  at
# 2016-07-01,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-05,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-06,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-07,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-08,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-11,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-12,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-13,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-14,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-15,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-18,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-19,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-20,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-21,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-22,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-25,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# 2016-07-26,  5.5700,       HAS Position at XLF XLI XLP,  and  at  XLU XLV XLY
# ...
# 2017-04-21,  56.6900,       HAS Position at ,  and  at
# 2017-04-24,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-04-25,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-04-26,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-04-27,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-04-28,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-01,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-02,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-03,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-04,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-05,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-08,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-09,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-10,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-11,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-12,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-15,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-16,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-17,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-18,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-19,  14.2900,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-22,  14.2900,       HAS Position at ,  and  at
# 2017-05-23,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-24,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-25,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-26,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-30,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-05-31,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-01,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-02,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-05,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-06,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-07,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-08,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-09,  10.2600,       HAS Position at ,  and  at
# 2017-06-12,  28.2600,       HAS Position at XLB XLE XLF,  and  at  XLK XLU XLY
# 2017-06-13,  28.2600,       HAS Position at ,  and  at
# 2017-06-14,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-15,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-16,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-19,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-20,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-21,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-22,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-23,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-26,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-27,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-28,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-29,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-06-30,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-03,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-05,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-06,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-07,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-10,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-11,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-12,  1.4400,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLV
# 2017-07-13,  1.4400,       HAS Position at ,  and  at
# 2017-07-14,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-17,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-18,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-19,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-20,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-21,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-24,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-25,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-26,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-27,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-28,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-07-31,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-01,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-02,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-03,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-04,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-07,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-08,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-09,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-10,  -14.4300,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-08-11,  -14.4300,       HAS Position at ,  and  at
# 2017-08-14,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-15,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-16,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-17,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-18,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-21,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-22,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-23,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-24,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-25,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-28,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-29,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-30,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-08-31,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-09-01,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-09-05,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-09-06,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-09-07,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-09-08,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-09-11,  10.9900,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLU
# 2017-09-12,  10.9900,       HAS Position at ,  and  at
# 2017-09-13,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-14,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-15,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-18,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-19,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-20,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-21,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-22,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-25,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-26,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-27,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-28,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-09-29,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-02,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-03,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-04,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-05,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-06,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-09,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-10,  11.9000,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-11,  11.9000,       HAS Position at ,  and  at
# 2017-10-12,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-13,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-16,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-17,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-18,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-19,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-20,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-23,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-24,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-25,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-26,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-27,  51.4400,       HAS Position at XLB XLE XLK,  and  at  XLP XLV XLY
# 2017-10-30,  51.4400,       HAS Position at ,  and  at
# 2017-10-31,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-01,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-02,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-03,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-06,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-07,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-08,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-09,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-10,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-13,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-14,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-15,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-16,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-17,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-20,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-21,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-22,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-24,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-27,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-28,  82.5000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-11-29,  82.5000,       HAS Position at ,  and  at
# 2017-11-30,  -12.7000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-12-01,  -12.7000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-12-04,  -12.7000,       HAS Position at XLB XLE XLF,  and  at  XLK XLP XLY
# 2017-12-05,  -12.7000,       HAS Position at ,  and  at
# 2017-12-06,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-07,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-08,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-11,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-12,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-13,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-14,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-15,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-18,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-19,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-20,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-21,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-22,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-26,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-27,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-28,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2017-12-29,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2018-01-02,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2018-01-03,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2018-01-04,  10.2600,       HAS Position at XLE XLF XLI,  and  at  XLK XLP XLU
# 2018-01-05,  10.2600,       HAS Position at ,  and  at
# 2018-01-08,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-09,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-10,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-11,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-12,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-16,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-17,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-18,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-19,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-22,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-23,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-24,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-25,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-26,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-29,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-30,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-01-31,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-02-01,  19.8900,       HAS Position at XLB XLE XLI,  and  at  XLK XLP XLU
# 2018-02-02,  19.8900,       HAS Position at ,  and  at
# 2018-02-05,  9.6800,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2018-02-06,  9.6800,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2018-02-07,  9.6800,       HAS Position at XLB XLE XLF,  and  at  XLP XLV XLY
# 2018-02-08,  9.6800,       HAS Position at ,  and  at
#
# Final Portfolio Value: 100518.02
# Sharpe Ratio: OrderedDict([('sharperatio', -6.616400722999124)])
# Max Draw Down: OrderedDict([('maxdrawdown', 0.6951804319052384), ('maxdrawdownperiod', 485)])

# %%
df2 = pd.DataFrame(BackTradingStrategy.path)
print(df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ef6e1c8da9fc> in <module>()
# ----> 1 df2 = pd.DataFrame(BackTradingStrategy.path)
#       2 print(df2)
#
# AttributeError: type object 'BackTradingStrategy' has no attribute 'path'

# %%
# calculate pnl using excel data
import pandas as pd
import matplotlib.pyplot as plt

dtime = pd.read_csv('datetime.csv')
data = pd.read_csv('0410-ETFbacktesting-Scored.csv').fillna(value = 0)
data = data[:1260]

df = data[data.columns[-9:]].copy()
df.columns = symbols
df['datetime'] = dtime[['datetime']].copy()

n = len(df)
df['cumulative_pnl'] = df['XLB']

cpnl = 0.
count_plus = 0
count_minus = 0

for t in range(n):
    pnl = 0.
    for i in range(len(symbols)):
        profit = df[symbols[i]].iloc[t]
        # print('profit = ', profit)
        pnl = pnl + profit
        if (profit > 0.):
            count_plus +=1
        elif (profit < 0.):
            count_minus +=1
         
    cpnl = cpnl + pnl
    # print('cpnl = ', cpnl)
    df['cumulative_pnl'].iloc[t] = cpnl

# %%
plus_percent = 1.0*count_plus/(count_plus*1.0+count_minus*1.0) 
print('percentage of trading that make positive profits = ', plus_percent)

# %%
# convert string to datetime
df["datetime"] = df["datetime"].apply(lambda x: datetime.strptime(x,"%m/%d/%Y"))

# plot PNL figures 
plt.figure(figsize=(16, 4))
plt.plot(df['datetime'], df['cumulative_pnl'] ,'.') 
plt.xlabel("Time")
plt.ylabel("cumulative pnl")
plt.title("Daily PNL")
plt.show()

# %%
df.to_csv(r'hmm_regime_wealth_Scored_v1.csv',header=list(df),index=list(df.index),sep=",",mode="a")

# %%
data = pd.read_csv('0410-ETFbacktesting-hmm-pnl.csv')
df = data[:1260]
# convert string to datetime
df["datetime"] = df["datetime"].apply(lambda x: datetime.strptime(x,"%m/%d/%Y"))

# plot figures for pnl of all versions
plt.figure(figsize=(16, 4))
plt.plot(df['datetime'], df['pnl_scored_v1'], label = 'pnl_scored_v1 SR = -5.989')
plt.plot(df['datetime'], df['pnl_scored_v2'], label = 'pnl_scored_v2 SR = -6.616')
plt.plot(df['datetime'], df['pnl_6m'], label = 'pnl_06m SR = -5.930')
plt.plot(df['datetime'], df['pnl_8m'], label = 'pnl_08m SR = -6.478')
plt.plot(df['datetime'], df['pnl_10m'], label = 'pnl_10m SR = -5.239')
plt.plot(df['datetime'], df['pnl_12m'], label = 'pnl_12m SR = -4.872')
plt.legend(loc='best')
plt.show()
